# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras_preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
# %matplotlib inline
# Out:
# 2022-11-09 02:57:06.362704: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 02:57:07.210556: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-09 02:57:08.536065: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 02:57:08.536407: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 02:57:08.536420: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv("df_with_gcs.txt",sep=',',header=0)

# %%
#划分训练测试集
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# 处理词向量

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 切分词汇
def cut(data):
    cut= [s.split() for s in data['TriageNote'].astype(str)]
    return cut

# %%
train_text=cut(train_set)
test_text=cut(test_set)
sentences=train_text+test_text

# %%
#得到最大句子长度
num_list=[len(one) for one in sentences]
max(num_list)
# Out:
# 57

# %%
maxLen=64

# %%
#处理label->one_hot
from sklearn.preprocessing import LabelEncoder

def encodelabel(data):
    le = LabelEncoder()
    resultLable=le.fit_transform(data['DISPOSITION'])
    return resultLable

# %%
train_lable=encodelabel(train_set)
test_lable=encodelabel(test_set)

# %%
wvmodel = word2vec.Word2Vec.load("./word2vec_all.model")
# Out:
# 2022-11-09 02:57:10,542 : INFO : loading Word2Vec object from ./word2vec_all.model
# 2022-11-09 02:57:10,608 : INFO : loading wv recursively from ./word2vec_all.model.wv.* with mmap=None
# 2022-11-09 02:57:10,609 : INFO : setting ignored attribute cum_table to None
# 2022-11-09 02:57:10,699 : INFO : Word2Vec lifecycle event {'fname': './word2vec_all.model', 'datetime': '2022-11-09T02:57:10.699816', 'gensim': '4.2.0', 'python': '3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]', 'platform': 'Linux-5.15.68.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'loaded'}

# %%
nekg=np.load('./embedding/nekg 1-999 100d.npy')
nekg
# Out:
# array([[-0.03946331, -0.02480048,  0.06082289, ..., -0.01568387,
#          0.05039275,  0.03724619],
#        [-0.03825712, -0.02397725,  0.05963894, ..., -0.01502065,
#          0.05186065,  0.03724643],
#        [-0.03705093, -0.02315403,  0.05845498, ..., -0.01435742,
#          0.05332854,  0.03724668],
#        ...,
#        [ 0.06336232, -0.04929246, -0.02796983, ...,  0.03513284,
#         -0.04742226,  0.04023478],
#        [ 0.06356958, -0.04936811, -0.02988294, ...,  0.03573058,
#         -0.04924951,  0.03923785],
#        [ 0.06377684, -0.04944375, -0.03179605, ...,  0.03632831,
#         -0.05107678,  0.03824091]])

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab = tokenizer.word_index

# %%
#特征数字编号，不足的话会在前面补充0
trainID = tokenizer.texts_to_sequences(train_text)
# print(trainID)
testID = tokenizer.texts_to_sequences(test_text)
trainSeq=pad_sequences(trainID,maxlen=maxLen)
#print(trainSeq)
testSeq=pad_sequences(testID,maxlen=maxLen)

#标签的独热编码
trainCate = to_categorical(train_lable, num_classes=2)  # 将标签转换为one-hot编码
#print(trainCate)
testCate= to_categorical(test_lable, num_classes=2)  # 将标签转换为one-hot编码

# %%
def nekg_embed(n0):
    n1=int(n0)
    n2=int(n0)+1
    s1=(n2-n0)/(n2-n1)
    s2=(n0-n1)/(n2-n1)
    return s1*nekg[n1]+s2*nekg[n2]

# %%
#利用训练后的word2vec自定义Embedding的训练矩阵，每行代表一个词（结合独热码和矩阵乘法理解）
embedding_matrix = np.zeros((len(vocab) + 1, 100))
for word, i in vocab.items():
    try:
        if(word.isdigit()==False):#对word用word2vec
            embedding_vector = wvmodel.wv[str(word)]
        else:#对number用nekg
            if (int(float(word))<=998):
                embedding_vector =  nekg_embed(float(word))
            else:
                embedding_vector = wvmodel.wv[str(word)]
        embedding_matrix[i] = embedding_vector    
    except KeyError:
        continue

# %%
## 定义LSTM模型
batch_size=256
inputs = Input(name='inputs',shape=[maxLen])
embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
model=Sequential()
model.add(embedder)
model.add(LSTM(64))
model.add(Dense(64,activation="sigmoid",name="FC1"))
model.add(Dropout(0.4))
model.add(Dense(2,activation="softmax",name="FC2"))
model.summary()
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
#reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
model.save("LSTM")
# Out:
# 2022-11-09 02:57:11.487030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-09 02:57:11.716791: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 02:57:11.716815: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-09 02:57:11.719434: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 64, 100)           806300
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 205ms/step - loss: 0.8026 - accuracy: 0.5126 - val_loss: 0.6745 - val_accuracy: 0.5812
# Epoch 2/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7157 - accuracy: 0.5240 - val_loss: 0.6371 - val_accuracy: 0.7338
# Epoch 3/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6931 - accuracy: 0.5914 - val_loss: 0.6620 - val_accuracy: 0.5909
# Epoch 4/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6704 - accuracy: 0.6060 - val_loss: 0.5954 - val_accuracy: 0.7143
# Epoch 5/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6157 - accuracy: 0.6661 - val_loss: 0.5672 - val_accuracy: 0.7208
# Epoch 6/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5942 - accuracy: 0.7059 - val_loss: 0.5479 - val_accuracy: 0.7597
# Epoch 7/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.5352 - accuracy: 0.7514 - val_loss: 0.6913 - val_accuracy: 0.6299
# Epoch 8/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5403 - accuracy: 0.7400 - val_loss: 0.5476 - val_accuracy: 0.7760
# Epoch 9/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.5178 - accuracy: 0.7571 - val_loss: 0.5219 - val_accuracy: 0.7597
# Epoch 10/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4668 - accuracy: 0.7929 - val_loss: 0.5154 - val_accuracy: 0.7597
# Epoch 11/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4227 - accuracy: 0.8359 - val_loss: 0.6821 - val_accuracy: 0.6818
# Epoch 12/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4542 - accuracy: 0.8099 - val_loss: 0.5091 - val_accuracy: 0.7825
# Epoch 13/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3884 - accuracy: 0.8465 - val_loss: 0.6601 - val_accuracy: 0.7143
# Epoch 14/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3554 - accuracy: 0.8619 - val_loss: 0.5595 - val_accuracy: 0.7662
# Epoch 15/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.3432 - accuracy: 0.8716 - val_loss: 0.5240 - val_accuracy: 0.7792
# Epoch 16/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3077 - accuracy: 0.8830 - val_loss: 0.6828 - val_accuracy: 0.7435
# Epoch 17/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2653 - accuracy: 0.9025 - val_loss: 0.5219 - val_accuracy: 0.7955
# 2022-11-09 02:57:25,040 : WARNING : Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM/assets
# 2022-11-09 02:57:25,714 : INFO : Assets written to: LSTM/assets

# %%
#预测与评估
mainModel = load_model('LSTM')
result = mainModel.predict(testSeq)  # 预测样本属于每个类别的概率
score = mainModel.evaluate(testSeq,
                           testCate,
                           batch_size=32)
print(score)
# Out:
# 6/6 [==============================] - 1s 15ms/step
# 6/6 [==============================] - 1s 13ms/step - loss: 0.6550 - accuracy: 0.7310
# [0.6550281643867493, 0.7309941649436951]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

# %%
score_list=[]
for i in range(10):
    ## 定义LSTM模型
    batch_size=256
    inputs = Input(name='inputs',shape=[maxLen])
    embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
    model=Sequential()
    model.add(embedder)
    model.add(LSTM(64))
    model.add(Dense(64,activation="sigmoid",name="FC1"))
    model.add(Dropout(0.4,seed=12))
    model.add(Dense(2,activation="softmax",name="FC2"))
    model.summary()
    model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
    history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
    result = model.predict(testSeq)  # 预测样本属于每个类别的概率
    score = model.evaluate(testSeq,
                               testCate,
                               batch_size=32)
    score_list.append(score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 64, 100)           806300
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 206ms/step - loss: 0.7383 - accuracy: 0.5361 - val_loss: 0.6818 - val_accuracy: 0.5909
# Epoch 2/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.7453 - accuracy: 0.5248 - val_loss: 0.6665 - val_accuracy: 0.5844
# Epoch 3/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.7119 - accuracy: 0.5670 - val_loss: 0.6269 - val_accuracy: 0.6818
# Epoch 4/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6743 - accuracy: 0.6052 - val_loss: 0.6134 - val_accuracy: 0.6721
# Epoch 5/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6376 - accuracy: 0.6604 - val_loss: 0.6302 - val_accuracy: 0.6429
# Epoch 6/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.5731 - accuracy: 0.7084 - val_loss: 0.5315 - val_accuracy: 0.7532
# Epoch 7/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.5874 - accuracy: 0.7181 - val_loss: 0.5287 - val_accuracy: 0.7532
# Epoch 8/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5091 - accuracy: 0.7725 - val_loss: 0.6236 - val_accuracy: 0.6948
# Epoch 9/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.5099 - accuracy: 0.7587 - val_loss: 0.5906 - val_accuracy: 0.6818
# Epoch 10/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4675 - accuracy: 0.7920 - val_loss: 0.5383 - val_accuracy: 0.7468
# Epoch 11/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4920 - accuracy: 0.7750 - val_loss: 0.5071 - val_accuracy: 0.7695
# Epoch 12/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4279 - accuracy: 0.8262 - val_loss: 0.5149 - val_accuracy: 0.7662
# Epoch 13/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.3528 - accuracy: 0.8668 - val_loss: 0.7075 - val_accuracy: 0.6429
# Epoch 14/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.3780 - accuracy: 0.8611 - val_loss: 0.5776 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3882 - accuracy: 0.8505 - val_loss: 0.5842 - val_accuracy: 0.7273
# Epoch 16/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.3126 - accuracy: 0.8855 - val_loss: 0.6437 - val_accuracy: 0.7078
# 6/6 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7192 - accuracy: 0.6725
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 64, 100)           806300
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 194ms/step - loss: 0.7874 - accuracy: 0.5118 - val_loss: 0.6874 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.7429 - accuracy: 0.5012 - val_loss: 0.6731 - val_accuracy: 0.5390
# Epoch 3/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7085 - accuracy: 0.5556 - val_loss: 0.6208 - val_accuracy: 0.7078
# Epoch 4/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6667 - accuracy: 0.6442 - val_loss: 0.5793 - val_accuracy: 0.7305
# Epoch 5/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6131 - accuracy: 0.6767 - val_loss: 0.5563 - val_accuracy: 0.7403
# Epoch 6/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5993 - accuracy: 0.7076 - val_loss: 0.5666 - val_accuracy: 0.7110
# Epoch 7/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5307 - accuracy: 0.7482 - val_loss: 0.6204 - val_accuracy: 0.7045
# Epoch 8/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5476 - accuracy: 0.7425 - val_loss: 0.5274 - val_accuracy: 0.7468
# Epoch 9/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.5059 - accuracy: 0.7790 - val_loss: 0.7384 - val_accuracy: 0.6331
# Epoch 10/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5059 - accuracy: 0.7937 - val_loss: 0.5482 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4425 - accuracy: 0.8148 - val_loss: 0.5309 - val_accuracy: 0.7662
# Epoch 12/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4462 - accuracy: 0.8099 - val_loss: 0.5522 - val_accuracy: 0.7338
# Epoch 13/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.3619 - accuracy: 0.8611 - val_loss: 0.5863 - val_accuracy: 0.7403
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7269 - accuracy: 0.6901
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 64, 100)           806300
#
#  lstm_3 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 195ms/step - loss: 0.7681 - accuracy: 0.5240 - val_loss: 0.6817 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7407 - accuracy: 0.5199 - val_loss: 0.6518 - val_accuracy: 0.6883
# Epoch 3/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7459 - accuracy: 0.5361 - val_loss: 0.6269 - val_accuracy: 0.7175
# Epoch 4/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6994 - accuracy: 0.5890 - val_loss: 0.5979 - val_accuracy: 0.7078
# Epoch 5/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.6263 - accuracy: 0.6580 - val_loss: 0.7888 - val_accuracy: 0.5844
# Epoch 6/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.7087 - accuracy: 0.5995 - val_loss: 0.5541 - val_accuracy: 0.7435
# Epoch 7/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.5339 - accuracy: 0.7474 - val_loss: 0.5465 - val_accuracy: 0.7338
# Epoch 8/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5294 - accuracy: 0.7522 - val_loss: 0.6272 - val_accuracy: 0.6299
# Epoch 9/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.5336 - accuracy: 0.7449 - val_loss: 0.5436 - val_accuracy: 0.7468
# Epoch 10/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.5267 - accuracy: 0.7595 - val_loss: 0.5327 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.4331 - accuracy: 0.8262 - val_loss: 0.5289 - val_accuracy: 0.7727
# Epoch 12/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4571 - accuracy: 0.8197 - val_loss: 0.6271 - val_accuracy: 0.6721
# Epoch 13/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4054 - accuracy: 0.8367 - val_loss: 0.5231 - val_accuracy: 0.7760
# Epoch 14/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4234 - accuracy: 0.8310 - val_loss: 0.5440 - val_accuracy: 0.7727
# Epoch 15/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.3579 - accuracy: 0.8627 - val_loss: 0.5911 - val_accuracy: 0.7500
# Epoch 16/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.2891 - accuracy: 0.9001 - val_loss: 0.5336 - val_accuracy: 0.7825
# Epoch 17/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4504 - accuracy: 0.8327 - val_loss: 0.5188 - val_accuracy: 0.7695
# Epoch 18/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2493 - accuracy: 0.9212 - val_loss: 0.5342 - val_accuracy: 0.7890
# Epoch 19/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.2305 - accuracy: 0.9236 - val_loss: 0.8898 - val_accuracy: 0.6591
# Epoch 20/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3567 - accuracy: 0.8652 - val_loss: 0.5470 - val_accuracy: 0.7890
# Epoch 21/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2019 - accuracy: 0.9391 - val_loss: 0.6803 - val_accuracy: 0.7305
# Epoch 22/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2717 - accuracy: 0.8920 - val_loss: 0.5695 - val_accuracy: 0.7857
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7342 - accuracy: 0.7193
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 64, 100)           806300
#
#  lstm_4 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 242ms/step - loss: 0.7680 - accuracy: 0.5118 - val_loss: 0.6842 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.7493 - accuracy: 0.5077 - val_loss: 0.6565 - val_accuracy: 0.6558
# Epoch 3/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6919 - accuracy: 0.5800 - val_loss: 0.6009 - val_accuracy: 0.6916
# Epoch 4/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.7167 - accuracy: 0.6044 - val_loss: 0.5961 - val_accuracy: 0.7403
# Epoch 5/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6194 - accuracy: 0.6621 - val_loss: 0.5647 - val_accuracy: 0.7240
# Epoch 6/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.6103 - accuracy: 0.6905 - val_loss: 0.6236 - val_accuracy: 0.6526
# Epoch 7/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.5484 - accuracy: 0.7352 - val_loss: 0.5275 - val_accuracy: 0.7597
# Epoch 8/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5721 - accuracy: 0.7271 - val_loss: 0.5279 - val_accuracy: 0.7597
# Epoch 9/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4873 - accuracy: 0.7937 - val_loss: 0.5595 - val_accuracy: 0.7370
# Epoch 10/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.5125 - accuracy: 0.7652 - val_loss: 0.5258 - val_accuracy: 0.7597
# Epoch 11/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.5022 - accuracy: 0.7734 - val_loss: 0.5503 - val_accuracy: 0.7370
# Epoch 12/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.4026 - accuracy: 0.8367 - val_loss: 0.5175 - val_accuracy: 0.7597
# Epoch 13/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.3790 - accuracy: 0.8489 - val_loss: 0.6174 - val_accuracy: 0.7208
# Epoch 14/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3591 - accuracy: 0.8595 - val_loss: 0.5458 - val_accuracy: 0.7760
# Epoch 15/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.4167 - accuracy: 0.8302 - val_loss: 0.5602 - val_accuracy: 0.7338
# Epoch 16/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2812 - accuracy: 0.9009 - val_loss: 0.5502 - val_accuracy: 0.7727
# Epoch 17/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.3541 - accuracy: 0.8692 - val_loss: 0.5263 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6241 - accuracy: 0.6725
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 64, 100)           806300
#
#  lstm_5 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 201ms/step - loss: 0.7748 - accuracy: 0.5110 - val_loss: 0.6609 - val_accuracy: 0.6786
# Epoch 2/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7076 - accuracy: 0.5540 - val_loss: 0.6132 - val_accuracy: 0.7403
# Epoch 3/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.6810 - accuracy: 0.6158 - val_loss: 0.5730 - val_accuracy: 0.7110
# Epoch 4/30
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6216 - accuracy: 0.6759 - val_loss: 0.5492 - val_accuracy: 0.7468
# Epoch 5/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.5996 - accuracy: 0.7011 - val_loss: 0.5685 - val_accuracy: 0.7208
# Epoch 6/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5588 - accuracy: 0.7295 - val_loss: 0.5326 - val_accuracy: 0.7565
# Epoch 7/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.5189 - accuracy: 0.7612 - val_loss: 0.5286 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.5007 - accuracy: 0.7782 - val_loss: 0.5247 - val_accuracy: 0.7630
# Epoch 9/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4731 - accuracy: 0.7872 - val_loss: 0.6016 - val_accuracy: 0.7013
# Epoch 10/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4443 - accuracy: 0.8034 - val_loss: 0.5925 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4431 - accuracy: 0.8115 - val_loss: 0.5199 - val_accuracy: 0.7630
# Epoch 12/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.3358 - accuracy: 0.8725 - val_loss: 0.5677 - val_accuracy: 0.7500
# Epoch 13/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4516 - accuracy: 0.8172 - val_loss: 0.5214 - val_accuracy: 0.7857
# Epoch 14/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.2876 - accuracy: 0.9033 - val_loss: 0.5450 - val_accuracy: 0.7760
# Epoch 15/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.3127 - accuracy: 0.8765 - val_loss: 0.5803 - val_accuracy: 0.7500
# Epoch 16/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.2695 - accuracy: 0.9058 - val_loss: 0.5577 - val_accuracy: 0.7857
# 6/6 [==============================] - 1s 18ms/step
# 6/6 [==============================] - 0s 19ms/step - loss: 0.7262 - accuracy: 0.7076
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 64, 100)           806300
#
#  lstm_6 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 221ms/step - loss: 0.7296 - accuracy: 0.5370 - val_loss: 0.6642 - val_accuracy: 0.6623
# Epoch 2/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6990 - accuracy: 0.5784 - val_loss: 0.6086 - val_accuracy: 0.6818
# Epoch 3/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6430 - accuracy: 0.6361 - val_loss: 0.5629 - val_accuracy: 0.7273
# Epoch 4/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6023 - accuracy: 0.6856 - val_loss: 0.5444 - val_accuracy: 0.7500
# Epoch 5/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5772 - accuracy: 0.7157 - val_loss: 0.5295 - val_accuracy: 0.7695
# Epoch 6/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.5733 - accuracy: 0.7222 - val_loss: 0.5596 - val_accuracy: 0.7175
# Epoch 7/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4902 - accuracy: 0.7839 - val_loss: 0.5736 - val_accuracy: 0.7013
# Epoch 8/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.5125 - accuracy: 0.7595 - val_loss: 0.5235 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.4409 - accuracy: 0.8172 - val_loss: 0.6333 - val_accuracy: 0.7013
# Epoch 10/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.4738 - accuracy: 0.7896 - val_loss: 0.5392 - val_accuracy: 0.7630
# Epoch 11/30
# 5/5 [==============================] - 1s 116ms/step - loss: 0.4224 - accuracy: 0.8229 - val_loss: 0.5134 - val_accuracy: 0.7727
# Epoch 12/30
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3761 - accuracy: 0.8562 - val_loss: 0.5534 - val_accuracy: 0.7532
# Epoch 13/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4059 - accuracy: 0.8213 - val_loss: 0.5343 - val_accuracy: 0.7727
# Epoch 14/30
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2892 - accuracy: 0.8936 - val_loss: 0.7527 - val_accuracy: 0.7110
# Epoch 15/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.3889 - accuracy: 0.8327 - val_loss: 0.5496 - val_accuracy: 0.7662
# Epoch 16/30
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2698 - accuracy: 0.9017 - val_loss: 0.6326 - val_accuracy: 0.7597
# 6/6 [==============================] - 1s 14ms/step
# 6/6 [==============================] - 0s 16ms/step - loss: 0.8561 - accuracy: 0.7018
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 64, 100)           806300
#
#  lstm_7 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 276ms/step - loss: 0.8083 - accuracy: 0.4817 - val_loss: 0.7083 - val_accuracy: 0.4740
# Epoch 2/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.7384 - accuracy: 0.5175 - val_loss: 0.6828 - val_accuracy: 0.5714
# Epoch 3/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.7260 - accuracy: 0.5305 - val_loss: 0.6765 - val_accuracy: 0.5617
# Epoch 4/30
# 5/5 [==============================] - 1s 147ms/step - loss: 0.6808 - accuracy: 0.5808 - val_loss: 0.6344 - val_accuracy: 0.6299
# Epoch 5/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.7181 - accuracy: 0.6093 - val_loss: 0.5902 - val_accuracy: 0.7208
# Epoch 6/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.6188 - accuracy: 0.6775 - val_loss: 0.5907 - val_accuracy: 0.6948
# Epoch 7/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6322 - accuracy: 0.6669 - val_loss: 0.5584 - val_accuracy: 0.7305
# Epoch 8/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5682 - accuracy: 0.7157 - val_loss: 0.5570 - val_accuracy: 0.7208
# Epoch 9/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.5406 - accuracy: 0.7474 - val_loss: 0.5709 - val_accuracy: 0.7078
# Epoch 10/30
# 5/5 [==============================] - 1s 124ms/step - loss: 0.5396 - accuracy: 0.7392 - val_loss: 0.5362 - val_accuracy: 0.7273
# Epoch 11/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4607 - accuracy: 0.8148 - val_loss: 0.5897 - val_accuracy: 0.7110
# Epoch 12/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4470 - accuracy: 0.8132 - val_loss: 0.5544 - val_accuracy: 0.7305
# Epoch 13/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4658 - accuracy: 0.7855 - val_loss: 0.5401 - val_accuracy: 0.7532
# Epoch 14/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.3548 - accuracy: 0.8603 - val_loss: 0.5640 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4452 - accuracy: 0.8188 - val_loss: 0.5349 - val_accuracy: 0.7597
# Epoch 16/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.3140 - accuracy: 0.8830 - val_loss: 0.6600 - val_accuracy: 0.7013
# Epoch 17/30
# 5/5 [==============================] - 1s 141ms/step - loss: 0.3766 - accuracy: 0.8448 - val_loss: 0.5441 - val_accuracy: 0.7662
# Epoch 18/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.3026 - accuracy: 0.8846 - val_loss: 0.5758 - val_accuracy: 0.7435
# Epoch 19/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.2429 - accuracy: 0.9115 - val_loss: 0.6176 - val_accuracy: 0.7240
# Epoch 20/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.2418 - accuracy: 0.9098 - val_loss: 0.7072 - val_accuracy: 0.7435
# 6/6 [==============================] - 1s 14ms/step
# 6/6 [==============================] - 0s 15ms/step - loss: 0.9127 - accuracy: 0.6608
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 100)           806300
#
#  lstm_8 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 272ms/step - loss: 0.7857 - accuracy: 0.4939 - val_loss: 0.6858 - val_accuracy: 0.5812
# Epoch 2/30
# 5/5 [==============================] - 1s 132ms/step - loss: 0.7399 - accuracy: 0.5020 - val_loss: 0.6622 - val_accuracy: 0.6364
# Epoch 3/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6904 - accuracy: 0.5719 - val_loss: 0.6476 - val_accuracy: 0.6136
# Epoch 4/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.6767 - accuracy: 0.5963 - val_loss: 0.5832 - val_accuracy: 0.7305
# Epoch 5/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6538 - accuracy: 0.6491 - val_loss: 0.5838 - val_accuracy: 0.7435
# Epoch 6/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.5752 - accuracy: 0.7059 - val_loss: 0.7159 - val_accuracy: 0.6331
# Epoch 7/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6092 - accuracy: 0.6840 - val_loss: 0.5457 - val_accuracy: 0.7403
# Epoch 8/30
# 5/5 [==============================] - 1s 132ms/step - loss: 0.5168 - accuracy: 0.7693 - val_loss: 0.5442 - val_accuracy: 0.7403
# Epoch 9/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.5310 - accuracy: 0.7530 - val_loss: 0.5402 - val_accuracy: 0.7532
# Epoch 10/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4863 - accuracy: 0.7782 - val_loss: 0.5329 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.4803 - accuracy: 0.7945 - val_loss: 0.5219 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4579 - accuracy: 0.8058 - val_loss: 0.5445 - val_accuracy: 0.7305
# Epoch 13/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.4283 - accuracy: 0.8164 - val_loss: 0.6511 - val_accuracy: 0.7078
# Epoch 14/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4142 - accuracy: 0.8327 - val_loss: 0.5243 - val_accuracy: 0.7662
# Epoch 15/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3227 - accuracy: 0.8773 - val_loss: 0.5496 - val_accuracy: 0.7565
# Epoch 16/30
# 5/5 [==============================] - 1s 116ms/step - loss: 0.3862 - accuracy: 0.8359 - val_loss: 0.5250 - val_accuracy: 0.7727
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6371 - accuracy: 0.6784
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 64, 100)           806300
#
#  lstm_9 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 201ms/step - loss: 0.7895 - accuracy: 0.4923 - val_loss: 0.6764 - val_accuracy: 0.6266
# Epoch 2/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7165 - accuracy: 0.5573 - val_loss: 0.6455 - val_accuracy: 0.6104
# Epoch 3/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6769 - accuracy: 0.6109 - val_loss: 0.6209 - val_accuracy: 0.6526
# Epoch 4/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6702 - accuracy: 0.6304 - val_loss: 0.5647 - val_accuracy: 0.7532
# Epoch 5/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.6329 - accuracy: 0.6751 - val_loss: 0.5766 - val_accuracy: 0.7078
# Epoch 6/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5338 - accuracy: 0.7352 - val_loss: 0.5480 - val_accuracy: 0.7565
# Epoch 7/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6147 - accuracy: 0.7132 - val_loss: 0.6360 - val_accuracy: 0.6591
# Epoch 8/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.5271 - accuracy: 0.7530 - val_loss: 0.5197 - val_accuracy: 0.7630
# Epoch 9/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4921 - accuracy: 0.7766 - val_loss: 0.5842 - val_accuracy: 0.7110
# Epoch 10/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4766 - accuracy: 0.7847 - val_loss: 0.5290 - val_accuracy: 0.7565
# Epoch 11/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4701 - accuracy: 0.7920 - val_loss: 0.5305 - val_accuracy: 0.7500
# Epoch 12/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4018 - accuracy: 0.8400 - val_loss: 0.5822 - val_accuracy: 0.7435
# Epoch 13/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4076 - accuracy: 0.8294 - val_loss: 0.5683 - val_accuracy: 0.7500
# 6/6 [==============================] - 1s 10ms/step
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6918 - accuracy: 0.6491
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 64, 100)           806300
#
#  lstm_10 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 206ms/step - loss: 0.8277 - accuracy: 0.4858 - val_loss: 0.6987 - val_accuracy: 0.5097
# Epoch 2/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7677 - accuracy: 0.4947 - val_loss: 0.6855 - val_accuracy: 0.5195
# Epoch 3/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.7206 - accuracy: 0.5410 - val_loss: 0.6838 - val_accuracy: 0.5162
# Epoch 4/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7216 - accuracy: 0.5313 - val_loss: 0.6429 - val_accuracy: 0.6461
# Epoch 5/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6910 - accuracy: 0.5987 - val_loss: 0.6133 - val_accuracy: 0.7045
# Epoch 6/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6585 - accuracy: 0.6377 - val_loss: 0.6437 - val_accuracy: 0.5909
# Epoch 7/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5888 - accuracy: 0.6872 - val_loss: 0.5576 - val_accuracy: 0.7208
# Epoch 8/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.5994 - accuracy: 0.6994 - val_loss: 0.5819 - val_accuracy: 0.7110
# Epoch 9/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.5276 - accuracy: 0.7425 - val_loss: 0.6221 - val_accuracy: 0.6461
# Epoch 10/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5276 - accuracy: 0.7571 - val_loss: 0.5378 - val_accuracy: 0.7468
# Epoch 11/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.5070 - accuracy: 0.7636 - val_loss: 0.5447 - val_accuracy: 0.7175
# Epoch 12/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.4572 - accuracy: 0.7961 - val_loss: 0.6793 - val_accuracy: 0.6786
# Epoch 13/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.4401 - accuracy: 0.8107 - val_loss: 0.6267 - val_accuracy: 0.7175
# Epoch 14/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.4630 - accuracy: 0.8132 - val_loss: 0.5375 - val_accuracy: 0.7435
# Epoch 15/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.3567 - accuracy: 0.8619 - val_loss: 0.5611 - val_accuracy: 0.7532
# Epoch 16/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3920 - accuracy: 0.8473 - val_loss: 0.6683 - val_accuracy: 0.6494
# Epoch 17/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.3350 - accuracy: 0.8798 - val_loss: 0.5819 - val_accuracy: 0.7565
# Epoch 18/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.2903 - accuracy: 0.8871 - val_loss: 0.7833 - val_accuracy: 0.6623
# Epoch 19/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3330 - accuracy: 0.8757 - val_loss: 0.5630 - val_accuracy: 0.7597
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6731 - accuracy: 0.6959

# %%
print('accuracy:'+str(sum(score_list)/len(score_list)))
# Out:
# accuracy:0.6847953200340271

# %%
score_list.sort()

# %%
score_list
# Out:
# [0.6491228342056274,
#  0.6608186960220337,
#  0.6725146174430847,
#  0.6725146174430847,
#  0.6783625483512878,
#  0.6900584697723389,
#  0.6959064602851868,
#  0.7017543911933899,
#  0.707602322101593,
#  0.719298243522644]
