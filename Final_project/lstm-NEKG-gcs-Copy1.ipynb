# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras_preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
# %matplotlib inline
# Out:
# 2022-11-09 17:37:43.582738: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 17:37:44.484395: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-09 17:37:45.881674: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 17:37:45.881998: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 17:37:45.882016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv("df_with_gcs.txt",sep=',',header=0)

# %%
#划分训练测试集
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# 处理词向量

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 切分词汇
def cut(data):
    cut= [s.split() for s in data['TriageNote'].astype(str)]
    return cut

# %%
train_text=cut(train_set)
test_text=cut(test_set)
sentences=train_text+test_text

# %%
#得到最大句子长度
num_list=[len(one) for one in sentences]
max(num_list)
# Out:
# 57

# %%
maxLen=64

# %%
#处理label->one_hot
from sklearn.preprocessing import LabelEncoder

def encodelabel(data):
    le = LabelEncoder()
    resultLable=le.fit_transform(data['DISPOSITION'])
    return resultLable

# %%
train_lable=encodelabel(train_set)
test_lable=encodelabel(test_set)

# %%
wvmodel = word2vec.Word2Vec.load("./word2vec_all.model")
# Out:
# 2022-11-09 17:37:47,460 : INFO : loading Word2Vec object from ./word2vec_all.model
# 2022-11-09 17:37:47,472 : INFO : loading wv recursively from ./word2vec_all.model.wv.* with mmap=None
# 2022-11-09 17:37:47,473 : INFO : setting ignored attribute cum_table to None
# 2022-11-09 17:37:47,570 : INFO : Word2Vec lifecycle event {'fname': './word2vec_all.model', 'datetime': '2022-11-09T17:37:47.570756', 'gensim': '4.2.0', 'python': '3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]', 'platform': 'Linux-5.15.68.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'loaded'}

# %%
import json
f = open('./embedding/TransD 1-999 300d.json')
nekg = json.load(f)
# nekg=np.load('./embedding/TransD 1-999 100d.npy')
# nekg

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab = tokenizer.word_index

# %%
#特征数字编号，不足的话会在前面补充0
trainID = tokenizer.texts_to_sequences(train_text)
# print(trainID)
testID = tokenizer.texts_to_sequences(test_text)
trainSeq=pad_sequences(trainID,maxlen=maxLen)
#print(trainSeq)
testSeq=pad_sequences(testID,maxlen=maxLen)

#标签的独热编码
trainCate = to_categorical(train_lable, num_classes=2)  # 将标签转换为one-hot编码
#print(trainCate)
testCate= to_categorical(test_lable, num_classes=2)  # 将标签转换为one-hot编码

# %%
def nekg_embed(n0):
    n1=int(n0)
    n2=int(n0)+1
    s1=(n2-n0)/(n2-n1)
    s2=(n0-n1)/(n2-n1)
    return s1*nekg[n1]+s2*nekg[n2]

# %%
#利用训练后的word2vec自定义Embedding的训练矩阵，每行代表一个词（结合独热码和矩阵乘法理解）
embedding_matrix = np.zeros((len(vocab) + 1, 100))
for word, i in vocab.items():
    try:
        if(word.isdigit()==False):#对word用word2vec
            embedding_vector = wvmodel.wv[str(word)]
        else:#对number用nekg
            if (int(float(word))<=998):
                embedding_vector =  nekg_embed(float(word))
            else:
                embedding_vector = wvmodel.wv[str(word)]
        embedding_matrix[i] = embedding_vector    
    except KeyError:
        continue

# %%
## 定义LSTM模型
batch_size=256
inputs = Input(name='inputs',shape=[maxLen])
embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
model=Sequential()
model.add(embedder)
model.add(LSTM(64))
model.add(Dense(64,activation="sigmoid",name="FC1"))
model.add(Dropout(0.4))
model.add(Dense(2,activation="softmax",name="FC2"))
model.summary()
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
#reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
model.save("LSTM")
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_39 (Embedding)    (None, 64, 100)           806300
#
#  lstm_34 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_34 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 202ms/step - loss: 0.7846 - accuracy: 0.5394 - val_loss: 0.6717 - val_accuracy: 0.6429
# Epoch 2/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7352 - accuracy: 0.5370 - val_loss: 0.6405 - val_accuracy: 0.6786
# Epoch 3/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.7113 - accuracy: 0.5776 - val_loss: 0.6628 - val_accuracy: 0.5974
# Epoch 4/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6580 - accuracy: 0.6288 - val_loss: 0.5729 - val_accuracy: 0.7338
# Epoch 5/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.6307 - accuracy: 0.6637 - val_loss: 0.5778 - val_accuracy: 0.7175
# Epoch 6/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.5834 - accuracy: 0.7076 - val_loss: 0.5754 - val_accuracy: 0.7240
# Epoch 7/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5529 - accuracy: 0.7335 - val_loss: 0.5444 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5127 - accuracy: 0.7571 - val_loss: 0.5598 - val_accuracy: 0.7403
# Epoch 9/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.5254 - accuracy: 0.7604 - val_loss: 0.5233 - val_accuracy: 0.7662
# Epoch 10/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4613 - accuracy: 0.8018 - val_loss: 0.5702 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4738 - accuracy: 0.7977 - val_loss: 0.5437 - val_accuracy: 0.7403
# Epoch 12/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4016 - accuracy: 0.8359 - val_loss: 0.5987 - val_accuracy: 0.7468
# Epoch 13/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4095 - accuracy: 0.8294 - val_loss: 0.5685 - val_accuracy: 0.7208
# Epoch 14/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.3790 - accuracy: 0.8359 - val_loss: 0.5417 - val_accuracy: 0.7597
# 2022-11-09 18:51:59,518 : WARNING : Found untraced functions such as lstm_cell_38_layer_call_fn, lstm_cell_38_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM/assets
# 2022-11-09 18:51:59,989 : INFO : Assets written to: LSTM/assets

# %%
#预测与评估
mainModel = load_model('LSTM')
result = mainModel.predict(testSeq)  # 预测样本属于每个类别的概率
score = mainModel.evaluate(testSeq,
                           testCate,
                           batch_size=32)
print(score)
# Out:
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6446 - accuracy: 0.6959
# [0.6446107029914856, 0.6959064602851868]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

# %%
score_list=[]
for i in range(10):
    ## 定义LSTM模型
    batch_size=256
    inputs = Input(name='inputs',shape=[maxLen])
    embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
    model=Sequential()
    model.add(embedder)
    model.add(LSTM(64))
    model.add(Dense(64,activation="sigmoid",name="FC1"))
    model.add(Dropout(0.4,seed=12))
    model.add(Dense(2,activation="softmax",name="FC2"))
    model.summary()
    model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
    history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
    result = model.predict(testSeq)  # 预测样本属于每个类别的概率
    score = model.evaluate(testSeq,
                               testCate,
                               batch_size=32)
    score_list.append(score[1])
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_40 (Embedding)    (None, 64, 100)           806300
#
#  lstm_35 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_35 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 195ms/step - loss: 0.7420 - accuracy: 0.5077 - val_loss: 0.6745 - val_accuracy: 0.6981
# Epoch 2/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7180 - accuracy: 0.5516 - val_loss: 0.7081 - val_accuracy: 0.5292
# Epoch 3/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6985 - accuracy: 0.6028 - val_loss: 0.6069 - val_accuracy: 0.7403
# Epoch 4/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6428 - accuracy: 0.6328 - val_loss: 0.6018 - val_accuracy: 0.6981
# Epoch 5/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6103 - accuracy: 0.6734 - val_loss: 0.5634 - val_accuracy: 0.7338
# Epoch 6/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5809 - accuracy: 0.7116 - val_loss: 0.6249 - val_accuracy: 0.6558
# Epoch 7/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5516 - accuracy: 0.7327 - val_loss: 0.5396 - val_accuracy: 0.7370
# Epoch 8/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.5314 - accuracy: 0.7506 - val_loss: 0.6293 - val_accuracy: 0.6883
# Epoch 9/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5167 - accuracy: 0.7693 - val_loss: 0.5927 - val_accuracy: 0.7013
# Epoch 10/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.4500 - accuracy: 0.8205 - val_loss: 0.5146 - val_accuracy: 0.7695
# Epoch 11/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4701 - accuracy: 0.8026 - val_loss: 0.5257 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3735 - accuracy: 0.8635 - val_loss: 0.5404 - val_accuracy: 0.7792
# Epoch 13/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4313 - accuracy: 0.8245 - val_loss: 0.5460 - val_accuracy: 0.7338
# Epoch 14/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.3227 - accuracy: 0.8765 - val_loss: 0.6101 - val_accuracy: 0.7403
# Epoch 15/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4386 - accuracy: 0.8172 - val_loss: 0.5245 - val_accuracy: 0.7760
# 6/6 [==============================] - 1s 14ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6376 - accuracy: 0.6725
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_41 (Embedding)    (None, 64, 100)           806300
#
#  lstm_36 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_36 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 189ms/step - loss: 0.8396 - accuracy: 0.4639 - val_loss: 0.6919 - val_accuracy: 0.5292
# Epoch 2/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7520 - accuracy: 0.5329 - val_loss: 0.6819 - val_accuracy: 0.5390
# Epoch 3/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7069 - accuracy: 0.5881 - val_loss: 0.7027 - val_accuracy: 0.4935
# Epoch 4/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7087 - accuracy: 0.5760 - val_loss: 0.6254 - val_accuracy: 0.7110
# Epoch 5/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6636 - accuracy: 0.6101 - val_loss: 0.6155 - val_accuracy: 0.6656
# Epoch 6/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.6351 - accuracy: 0.6491 - val_loss: 0.6038 - val_accuracy: 0.6396
# Epoch 7/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.5638 - accuracy: 0.7116 - val_loss: 0.7429 - val_accuracy: 0.5357
# Epoch 8/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5727 - accuracy: 0.7027 - val_loss: 0.5402 - val_accuracy: 0.7338
# Epoch 9/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5585 - accuracy: 0.7368 - val_loss: 0.5497 - val_accuracy: 0.7403
# Epoch 10/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4725 - accuracy: 0.7912 - val_loss: 0.6393 - val_accuracy: 0.6364
# Epoch 11/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5317 - accuracy: 0.7571 - val_loss: 0.5400 - val_accuracy: 0.7370
# Epoch 12/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.4118 - accuracy: 0.8278 - val_loss: 0.6631 - val_accuracy: 0.6331
# Epoch 13/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4070 - accuracy: 0.8408 - val_loss: 0.6749 - val_accuracy: 0.7078
# Epoch 14/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4454 - accuracy: 0.8115 - val_loss: 0.5439 - val_accuracy: 0.7662
# Epoch 15/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3407 - accuracy: 0.8627 - val_loss: 0.7148 - val_accuracy: 0.6429
# Epoch 16/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.3567 - accuracy: 0.8603 - val_loss: 0.5910 - val_accuracy: 0.7240
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6695 - accuracy: 0.7485
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_42 (Embedding)    (None, 64, 100)           806300
#
#  lstm_37 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_37 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 200ms/step - loss: 0.8279 - accuracy: 0.5150 - val_loss: 0.6759 - val_accuracy: 0.6591
# Epoch 2/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7348 - accuracy: 0.5353 - val_loss: 0.6650 - val_accuracy: 0.5584
# Epoch 3/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7031 - accuracy: 0.5662 - val_loss: 0.6606 - val_accuracy: 0.5552
# Epoch 4/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.6560 - accuracy: 0.6328 - val_loss: 0.6033 - val_accuracy: 0.6981
# Epoch 5/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.6589 - accuracy: 0.6434 - val_loss: 0.5466 - val_accuracy: 0.7338
# Epoch 6/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6338 - accuracy: 0.6864 - val_loss: 0.5600 - val_accuracy: 0.7175
# Epoch 7/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5417 - accuracy: 0.7368 - val_loss: 0.5398 - val_accuracy: 0.7403
# Epoch 8/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.5809 - accuracy: 0.7335 - val_loss: 0.5258 - val_accuracy: 0.7727
# Epoch 9/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4899 - accuracy: 0.7880 - val_loss: 0.5815 - val_accuracy: 0.7305
# Epoch 10/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4753 - accuracy: 0.7864 - val_loss: 0.6002 - val_accuracy: 0.7045
# Epoch 11/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4826 - accuracy: 0.7896 - val_loss: 0.5406 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.3948 - accuracy: 0.8408 - val_loss: 0.5200 - val_accuracy: 0.7695
# Epoch 13/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.4334 - accuracy: 0.8302 - val_loss: 0.7810 - val_accuracy: 0.6364
# Epoch 14/30
# 5/5 [==============================] - 2s 502ms/step - loss: 0.4095 - accuracy: 0.8310 - val_loss: 0.5177 - val_accuracy: 0.7727
# Epoch 15/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3238 - accuracy: 0.8765 - val_loss: 0.5716 - val_accuracy: 0.7532
# Epoch 16/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.3131 - accuracy: 0.8846 - val_loss: 0.6554 - val_accuracy: 0.7273
# Epoch 17/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3039 - accuracy: 0.8887 - val_loss: 0.5515 - val_accuracy: 0.7760
# Epoch 18/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.3161 - accuracy: 0.8781 - val_loss: 0.5712 - val_accuracy: 0.7500
# Epoch 19/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2187 - accuracy: 0.9334 - val_loss: 0.5893 - val_accuracy: 0.7792
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7549 - accuracy: 0.7135
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_43 (Embedding)    (None, 64, 100)           806300
#
#  lstm_38 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 4s 221ms/step - loss: 0.8081 - accuracy: 0.4947 - val_loss: 0.6894 - val_accuracy: 0.5714
# Epoch 2/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.7514 - accuracy: 0.5337 - val_loss: 0.6773 - val_accuracy: 0.5877
# Epoch 3/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.7231 - accuracy: 0.5313 - val_loss: 0.6422 - val_accuracy: 0.6753
# Epoch 4/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.7064 - accuracy: 0.5743 - val_loss: 0.6089 - val_accuracy: 0.6948
# Epoch 5/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.7123 - accuracy: 0.6304 - val_loss: 0.6187 - val_accuracy: 0.6201
# Epoch 6/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.6248 - accuracy: 0.6523 - val_loss: 0.6143 - val_accuracy: 0.6753
# Epoch 7/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5853 - accuracy: 0.7108 - val_loss: 0.7254 - val_accuracy: 0.5519
# Epoch 8/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5871 - accuracy: 0.6978 - val_loss: 0.5447 - val_accuracy: 0.7435
# Epoch 9/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5627 - accuracy: 0.7384 - val_loss: 0.5385 - val_accuracy: 0.7370
# Epoch 10/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.4626 - accuracy: 0.7896 - val_loss: 0.6032 - val_accuracy: 0.6656
# Epoch 11/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.4902 - accuracy: 0.7677 - val_loss: 0.5886 - val_accuracy: 0.7240
# Epoch 12/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4310 - accuracy: 0.8286 - val_loss: 0.6148 - val_accuracy: 0.6948
# Epoch 13/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4455 - accuracy: 0.8115 - val_loss: 0.5447 - val_accuracy: 0.7597
# Epoch 14/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.3883 - accuracy: 0.8522 - val_loss: 0.6114 - val_accuracy: 0.6623
# 6/6 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6438 - accuracy: 0.6667
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_44 (Embedding)    (None, 64, 100)           806300
#
#  lstm_39 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_39 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 239ms/step - loss: 0.7928 - accuracy: 0.4671 - val_loss: 0.6798 - val_accuracy: 0.6006
# Epoch 2/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.7400 - accuracy: 0.5183 - val_loss: 0.6657 - val_accuracy: 0.5877
# Epoch 3/30
# 5/5 [==============================] - 1s 124ms/step - loss: 0.6935 - accuracy: 0.5768 - val_loss: 0.7354 - val_accuracy: 0.5292
# Epoch 4/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6857 - accuracy: 0.6093 - val_loss: 0.6669 - val_accuracy: 0.6006
# Epoch 5/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6597 - accuracy: 0.6353 - val_loss: 0.6526 - val_accuracy: 0.5942
# Epoch 6/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.5766 - accuracy: 0.7108 - val_loss: 0.6034 - val_accuracy: 0.7045
# Epoch 7/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5716 - accuracy: 0.7124 - val_loss: 0.6087 - val_accuracy: 0.6688
# Epoch 8/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.5723 - accuracy: 0.7246 - val_loss: 0.5434 - val_accuracy: 0.7532
# Epoch 9/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.4900 - accuracy: 0.7855 - val_loss: 0.5575 - val_accuracy: 0.7435
# Epoch 10/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4840 - accuracy: 0.7790 - val_loss: 0.5418 - val_accuracy: 0.7370
# Epoch 11/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.4884 - accuracy: 0.7823 - val_loss: 0.5387 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.3980 - accuracy: 0.8318 - val_loss: 0.5493 - val_accuracy: 0.7500
# Epoch 13/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.4091 - accuracy: 0.8253 - val_loss: 0.5546 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.3371 - accuracy: 0.8749 - val_loss: 0.6612 - val_accuracy: 0.7110
# Epoch 15/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.3384 - accuracy: 0.8668 - val_loss: 0.5600 - val_accuracy: 0.7565
# Epoch 16/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.2468 - accuracy: 0.9155 - val_loss: 0.5909 - val_accuracy: 0.7727
# 6/6 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7331 - accuracy: 0.7018
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_45 (Embedding)    (None, 64, 100)           806300
#
#  lstm_40 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 249ms/step - loss: 0.7234 - accuracy: 0.5540 - val_loss: 0.6826 - val_accuracy: 0.4903
# Epoch 2/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.7193 - accuracy: 0.5524 - val_loss: 0.6476 - val_accuracy: 0.6104
# Epoch 3/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6914 - accuracy: 0.5841 - val_loss: 0.6538 - val_accuracy: 0.5812
# Epoch 4/30
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6388 - accuracy: 0.6499 - val_loss: 0.6950 - val_accuracy: 0.6331
# Epoch 5/30
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6201 - accuracy: 0.6751 - val_loss: 0.5431 - val_accuracy: 0.7500
# Epoch 6/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.5679 - accuracy: 0.7271 - val_loss: 0.5455 - val_accuracy: 0.7403
# Epoch 7/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.5173 - accuracy: 0.7669 - val_loss: 0.5347 - val_accuracy: 0.7500
# Epoch 8/30
# 5/5 [==============================] - 1s 137ms/step - loss: 0.5406 - accuracy: 0.7636 - val_loss: 0.5337 - val_accuracy: 0.7435
# Epoch 9/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4589 - accuracy: 0.8091 - val_loss: 0.5760 - val_accuracy: 0.7305
# Epoch 10/30
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4768 - accuracy: 0.7855 - val_loss: 0.6178 - val_accuracy: 0.7078
# Epoch 11/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4605 - accuracy: 0.8091 - val_loss: 0.5795 - val_accuracy: 0.7208
# Epoch 12/30
# 5/5 [==============================] - 1s 136ms/step - loss: 0.3809 - accuracy: 0.8489 - val_loss: 0.5909 - val_accuracy: 0.7662
# Epoch 13/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4425 - accuracy: 0.8253 - val_loss: 0.6177 - val_accuracy: 0.6818
# 6/6 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6509 - accuracy: 0.6725
# Model: "sequential_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_46 (Embedding)    (None, 64, 100)           806300
#
#  lstm_41 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_41 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 289ms/step - loss: 0.9442 - accuracy: 0.4833 - val_loss: 0.7005 - val_accuracy: 0.4935
# Epoch 2/30
# 5/5 [==============================] - 1s 167ms/step - loss: 0.7515 - accuracy: 0.4996 - val_loss: 0.6928 - val_accuracy: 0.5162
# Epoch 3/30
# 5/5 [==============================] - 1s 135ms/step - loss: 0.7451 - accuracy: 0.5134 - val_loss: 0.6798 - val_accuracy: 0.5422
# Epoch 4/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.7156 - accuracy: 0.5378 - val_loss: 0.7238 - val_accuracy: 0.4740
# Epoch 5/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.6951 - accuracy: 0.5800 - val_loss: 0.6630 - val_accuracy: 0.5487
# Epoch 6/30
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6832 - accuracy: 0.6084 - val_loss: 0.6595 - val_accuracy: 0.5649
# Epoch 7/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6293 - accuracy: 0.6531 - val_loss: 0.6669 - val_accuracy: 0.6039
# Epoch 8/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6051 - accuracy: 0.6734 - val_loss: 0.5922 - val_accuracy: 0.7110
# Epoch 9/30
# 5/5 [==============================] - 1s 138ms/step - loss: 0.5666 - accuracy: 0.7157 - val_loss: 0.5932 - val_accuracy: 0.6786
# Epoch 10/30
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5359 - accuracy: 0.7441 - val_loss: 0.5554 - val_accuracy: 0.7435
# Epoch 11/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4699 - accuracy: 0.8050 - val_loss: 0.6811 - val_accuracy: 0.6006
# Epoch 12/30
# 5/5 [==============================] - 1s 182ms/step - loss: 0.4760 - accuracy: 0.7847 - val_loss: 0.5343 - val_accuracy: 0.7532
# Epoch 13/30
# 5/5 [==============================] - 1s 165ms/step - loss: 0.4834 - accuracy: 0.7782 - val_loss: 0.6638 - val_accuracy: 0.6104
# Epoch 14/30
# 5/5 [==============================] - 1s 165ms/step - loss: 0.4324 - accuracy: 0.8262 - val_loss: 0.5440 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 1s 156ms/step - loss: 0.4120 - accuracy: 0.8237 - val_loss: 0.5827 - val_accuracy: 0.7045
# Epoch 16/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.3750 - accuracy: 0.8554 - val_loss: 0.5834 - val_accuracy: 0.7338
# Epoch 17/30
# 5/5 [==============================] - 1s 146ms/step - loss: 0.3572 - accuracy: 0.8489 - val_loss: 0.6712 - val_accuracy: 0.6721
# 6/6 [==============================] - 1s 21ms/step
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6518 - accuracy: 0.6959
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_47 (Embedding)    (None, 64, 100)           806300
#
#  lstm_42 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_42 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 4s 365ms/step - loss: 0.7638 - accuracy: 0.4915 - val_loss: 0.6846 - val_accuracy: 0.5292
# Epoch 2/30
# 5/5 [==============================] - 1s 159ms/step - loss: 0.7145 - accuracy: 0.5280 - val_loss: 0.7654 - val_accuracy: 0.5260
# Epoch 3/30
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7315 - accuracy: 0.5435 - val_loss: 0.6346 - val_accuracy: 0.6494
# Epoch 4/30
# 5/5 [==============================] - 1s 162ms/step - loss: 0.6384 - accuracy: 0.6426 - val_loss: 0.6086 - val_accuracy: 0.6591
# Epoch 5/30
# 5/5 [==============================] - 1s 186ms/step - loss: 0.6133 - accuracy: 0.6718 - val_loss: 0.6510 - val_accuracy: 0.6494
# Epoch 6/30
# 5/5 [==============================] - 1s 176ms/step - loss: 0.6106 - accuracy: 0.6970 - val_loss: 0.5576 - val_accuracy: 0.7370
# Epoch 7/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.5417 - accuracy: 0.7506 - val_loss: 0.5299 - val_accuracy: 0.7565
# Epoch 8/30
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5024 - accuracy: 0.7790 - val_loss: 0.6302 - val_accuracy: 0.6396
# Epoch 9/30
# 5/5 [==============================] - 1s 139ms/step - loss: 0.5361 - accuracy: 0.7490 - val_loss: 0.5324 - val_accuracy: 0.7565
# Epoch 10/30
# 5/5 [==============================] - 1s 160ms/step - loss: 0.4757 - accuracy: 0.7977 - val_loss: 0.5911 - val_accuracy: 0.7045
# Epoch 11/30
# 5/5 [==============================] - 1s 166ms/step - loss: 0.4490 - accuracy: 0.8188 - val_loss: 0.5282 - val_accuracy: 0.7695
# Epoch 12/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.3905 - accuracy: 0.8343 - val_loss: 0.6564 - val_accuracy: 0.6688
# Epoch 13/30
# 5/5 [==============================] - 1s 149ms/step - loss: 0.4092 - accuracy: 0.8359 - val_loss: 0.6536 - val_accuracy: 0.7110
# Epoch 14/30
# 5/5 [==============================] - 1s 151ms/step - loss: 0.3890 - accuracy: 0.8408 - val_loss: 0.5375 - val_accuracy: 0.7630
# Epoch 15/30
# 5/5 [==============================] - 1s 157ms/step - loss: 0.3110 - accuracy: 0.8838 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 16/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.2823 - accuracy: 0.8976 - val_loss: 0.6330 - val_accuracy: 0.7435
# 6/6 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 14ms/step - loss: 0.7971 - accuracy: 0.6550
# Model: "sequential_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_48 (Embedding)    (None, 64, 100)           806300
#
#  lstm_43 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_43 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 243ms/step - loss: 0.8191 - accuracy: 0.5053 - val_loss: 0.6939 - val_accuracy: 0.4903
# Epoch 2/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.7372 - accuracy: 0.4980 - val_loss: 0.6751 - val_accuracy: 0.5747
# Epoch 3/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.7268 - accuracy: 0.5402 - val_loss: 0.6833 - val_accuracy: 0.5065
# Epoch 4/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.6878 - accuracy: 0.5760 - val_loss: 0.6373 - val_accuracy: 0.6623
# Epoch 5/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.6747 - accuracy: 0.5922 - val_loss: 0.5929 - val_accuracy: 0.7208
# Epoch 6/30
# 5/5 [==============================] - 1s 154ms/step - loss: 0.6191 - accuracy: 0.6759 - val_loss: 0.5634 - val_accuracy: 0.7370
# Epoch 7/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.6232 - accuracy: 0.6759 - val_loss: 0.5675 - val_accuracy: 0.7175
# Epoch 8/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.5715 - accuracy: 0.7116 - val_loss: 0.5974 - val_accuracy: 0.7078
# Epoch 9/30
# 5/5 [==============================] - 1s 130ms/step - loss: 0.5211 - accuracy: 0.7652 - val_loss: 0.5488 - val_accuracy: 0.7435
# Epoch 10/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.5358 - accuracy: 0.7490 - val_loss: 0.5527 - val_accuracy: 0.7273
# Epoch 11/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4510 - accuracy: 0.8107 - val_loss: 0.6878 - val_accuracy: 0.6104
# Epoch 12/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4265 - accuracy: 0.8262 - val_loss: 0.5570 - val_accuracy: 0.7403
# Epoch 13/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4367 - accuracy: 0.8262 - val_loss: 0.5489 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 1s 137ms/step - loss: 0.4140 - accuracy: 0.8318 - val_loss: 0.5639 - val_accuracy: 0.7175
# 6/6 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6328 - accuracy: 0.6959
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_49 (Embedding)    (None, 64, 100)           806300
#
#  lstm_44 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_44 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 4s 269ms/step - loss: 0.7865 - accuracy: 0.5004 - val_loss: 0.6737 - val_accuracy: 0.6948
# Epoch 2/30
# 5/5 [==============================] - 1s 135ms/step - loss: 0.7283 - accuracy: 0.5321 - val_loss: 0.6576 - val_accuracy: 0.5747
# Epoch 3/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.7008 - accuracy: 0.5760 - val_loss: 0.7154 - val_accuracy: 0.5617
# Epoch 4/30
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6932 - accuracy: 0.6117 - val_loss: 0.6412 - val_accuracy: 0.6299
# Epoch 5/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.5919 - accuracy: 0.6791 - val_loss: 0.6262 - val_accuracy: 0.6818
# Epoch 6/30
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6041 - accuracy: 0.6986 - val_loss: 0.5562 - val_accuracy: 0.7338
# Epoch 7/30
# 5/5 [==============================] - 1s 135ms/step - loss: 0.5454 - accuracy: 0.7384 - val_loss: 0.5325 - val_accuracy: 0.7435
# Epoch 8/30
# 5/5 [==============================] - 1s 137ms/step - loss: 0.5312 - accuracy: 0.7636 - val_loss: 0.5522 - val_accuracy: 0.7370
# Epoch 9/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.5083 - accuracy: 0.7734 - val_loss: 0.5247 - val_accuracy: 0.7403
# Epoch 10/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4389 - accuracy: 0.8067 - val_loss: 0.5430 - val_accuracy: 0.7500
# Epoch 11/30
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4694 - accuracy: 0.8002 - val_loss: 0.5208 - val_accuracy: 0.7500
# Epoch 12/30
# 5/5 [==============================] - 1s 167ms/step - loss: 0.4706 - accuracy: 0.7985 - val_loss: 0.5149 - val_accuracy: 0.7500
# Epoch 13/30
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3427 - accuracy: 0.8643 - val_loss: 0.5464 - val_accuracy: 0.7662
# Epoch 14/30
# 5/5 [==============================] - 1s 150ms/step - loss: 0.3756 - accuracy: 0.8554 - val_loss: 0.7424 - val_accuracy: 0.6688
# Epoch 15/30
# 5/5 [==============================] - 1s 158ms/step - loss: 0.3513 - accuracy: 0.8733 - val_loss: 0.5345 - val_accuracy: 0.7695
# Epoch 16/30
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3582 - accuracy: 0.8587 - val_loss: 0.5485 - val_accuracy: 0.7403
# Epoch 17/30
# 5/5 [==============================] - 1s 139ms/step - loss: 0.2493 - accuracy: 0.9139 - val_loss: 0.5846 - val_accuracy: 0.7597
# 6/6 [==============================] - 1s 17ms/step
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7568 - accuracy: 0.6725

# %%
print('accuracy:'+str(sum(score_list)/len(score_list)))
# Out:
# accuracy:0.689473694562912

# %%
score_list.sort()

# %%
score_list
# Out:
# [0.6549707651138306,
#  0.6666666865348816,
#  0.6725146174430847,
#  0.6725146174430847,
#  0.6725146174430847,
#  0.6959064602851868,
#  0.6959064602851868,
#  0.7017543911933899,
#  0.7134503126144409,
#  0.7485380172729492]
