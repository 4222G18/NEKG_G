# %%
import sys
import os
path_father = os.path.abspath(r'..')
path_father
# sys.path.append(path_father)
# Out:
# '/home/egbert_jing/github/NEKG_G/Final_project'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras_preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
# %matplotlib inline
# Out:
# 2022-11-27 16:55:25.014300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-27 16:55:25.812259: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-27 16:55:27.059192: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-27 16:55:27.059357: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-27 16:55:27.059364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv(path_father + "/df_with_gcs.txt",sep=',',header=0)

# %%
#划分训练测试集
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# 处理词向量

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 切分词汇
def cut(data):
    cut= [s.split() for s in data['TriageNote'].astype(str)]
    return cut

# %%
train_text=cut(train_set)
test_text=cut(test_set)
sentences=train_text+test_text

# %%
#得到最大句子长度
num_list=[len(one) for one in sentences]
max(num_list)
# Out:
# 57

# %%
maxLen=64

# %%
#处理label->one_hot
from sklearn.preprocessing import LabelEncoder

def encodelabel(data):
    le = LabelEncoder()
    resultLable=le.fit_transform(data['DISPOSITION'])
    return resultLable

# %%
train_lable=encodelabel(train_set)
test_lable=encodelabel(test_set)

# %%
wvmodel = word2vec.Word2Vec.load("./word2vec_all.model")
# Out:
# 2022-11-27 16:55:29,181 : INFO : loading Word2Vec object from ./word2vec_all.model
# 2022-11-27 16:55:29,197 : INFO : loading wv recursively from ./word2vec_all.model.wv.* with mmap=None
# 2022-11-27 16:55:29,198 : INFO : setting ignored attribute cum_table to None
# 2022-11-27 16:55:29,284 : INFO : Word2Vec lifecycle event {'fname': './word2vec_all.model', 'datetime': '2022-11-27T16:55:29.284261', 'gensim': '4.2.0', 'python': '3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]', 'platform': 'Linux-5.15.74.2-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'loaded'}

# %%
nekg=np.load(path_father + "/embedding/random.npy",allow_pickle=True)
nekg
# Out:
# array([[ 0.29711841,  0.27413251, -0.35730858, ...,  0.05089224,
#          0.93462405, -0.12650368],
#        [-0.75535134, -0.73600882,  0.17998657, ...,  0.16355494,
#         -0.63062939,  0.54375415],
#        [-0.36034961, -0.77011188, -0.54448113, ...,  0.28366931,
#         -0.47143449,  0.38299598],
#        ...,
#        [-0.61550167,  0.92051485,  0.50692087, ...,  0.52917218,
#          0.44885229, -0.62038646],
#        [ 0.92584645, -0.8583721 , -0.98693935, ..., -0.25457935,
#         -0.7431174 , -0.04987183],
#        [-0.00649053, -0.4951124 ,  0.76590084, ...,  0.42894894,
#          0.92919298,  0.38526575]])

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab = tokenizer.word_index

# %%
#特征数字编号，不足的话会在前面补充0
trainID = tokenizer.texts_to_sequences(train_text)
# print(trainID)
testID = tokenizer.texts_to_sequences(test_text)
trainSeq=pad_sequences(trainID,maxlen=maxLen)
#print(trainSeq)
testSeq=pad_sequences(testID,maxlen=maxLen)

#标签的独热编码
trainCate = to_categorical(train_lable, num_classes=2)  # 将标签转换为one-hot编码
#print(trainCate)
testCate= to_categorical(test_lable, num_classes=2)  # 将标签转换为one-hot编码

# %%
def nekg_embed(n0):
    n1=int(n0)
    n2=int(n0)+1
    s1=(n2-n0)/(n2-n1)
    s2=(n0-n1)/(n2-n1)
    return s1*nekg[n1]+s2*nekg[n2]

# %%
#利用训练后的word2vec自定义Embedding的训练矩阵，每行代表一个词（结合独热码和矩阵乘法理解）
embedding_matrix = np.zeros((len(vocab) + 1, 100))
for word, i in vocab.items():
    try:
        if(word.isdigit()==False):#对word用word2vec
            embedding_vector = wvmodel.wv[str(word)]
        else:#对number用nekg
            if (int(float(word))<=998):
                embedding_vector =  nekg_embed(float(word))
            else:
                embedding_vector = wvmodel.wv[str(word)]
        embedding_matrix[i] = embedding_vector    
    except KeyError:
        continue

# %%
## 定义LSTM模型
batch_size=256
inputs = Input(name='inputs',shape=[maxLen])
embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
model=Sequential()
model.add(embedder)
model.add(LSTM(64))
model.add(Dense(64,activation="sigmoid",name="FC1"))
model.add(Dropout(0.4))
model.add(Dense(2,activation="softmax",name="FC2"))
model.summary()
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
#reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
model.save("LSTM")
# Out:
# 2022-11-27 16:55:30.465016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-27 16:55:30.742324: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-27 16:55:30.742351: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-27 16:55:30.743912: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 64, 100)           806300
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 242ms/step - loss: 0.7826 - accuracy: 0.4793 - val_loss: 0.6757 - val_accuracy: 0.6136
# Epoch 2/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.7315 - accuracy: 0.5426 - val_loss: 0.6532 - val_accuracy: 0.5617
# Epoch 3/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6703 - accuracy: 0.6036 - val_loss: 0.6295 - val_accuracy: 0.6299
# Epoch 4/30
# 5/5 [==============================] - 0s 105ms/step - loss: 0.6333 - accuracy: 0.6613 - val_loss: 0.5519 - val_accuracy: 0.7305
# Epoch 5/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.5819 - accuracy: 0.7189 - val_loss: 0.5425 - val_accuracy: 0.7500
# Epoch 6/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.5168 - accuracy: 0.7644 - val_loss: 0.6459 - val_accuracy: 0.6786
# Epoch 7/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.5356 - accuracy: 0.7571 - val_loss: 0.5913 - val_accuracy: 0.6948
# Epoch 8/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4860 - accuracy: 0.7677 - val_loss: 0.5859 - val_accuracy: 0.7208
# Epoch 9/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4632 - accuracy: 0.7920 - val_loss: 0.5593 - val_accuracy: 0.7143
# Epoch 10/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.3855 - accuracy: 0.8522 - val_loss: 0.5706 - val_accuracy: 0.7468
# 2022-11-27 16:55:41,371 : WARNING : Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM/assets
# 2022-11-27 16:55:42,057 : INFO : Assets written to: LSTM/assets

# %%
#预测与评估
mainModel = load_model('LSTM')
result = mainModel.predict(testSeq)  # 预测样本属于每个类别的概率
score = mainModel.evaluate(testSeq,
                           testCate,
                           batch_size=32)
print(score)
# Out:
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6880 - accuracy: 0.6550
# [0.6880321502685547, 0.6549707651138306]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

# %%
score_list=[]
for i in range(10):
    ## 定义LSTM模型
    batch_size=256
    inputs = Input(name='inputs',shape=[maxLen])
    embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
    model=Sequential()
    model.add(embedder)
    model.add(LSTM(64))
    model.add(Dense(64,activation="sigmoid",name="FC1"))
    model.add(Dropout(0.4,seed=12))
    model.add(Dense(2,activation="softmax",name="FC2"))
    model.summary()
    model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
    history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
    result = model.predict(testSeq)  # 预测样本属于每个类别的概率
    score = model.evaluate(testSeq,
                               testCate,
                               batch_size=32)
    score_list.append(score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 64, 100)           806300
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 262ms/step - loss: 0.7719 - accuracy: 0.4915 - val_loss: 0.6789 - val_accuracy: 0.6656
# Epoch 2/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.7219 - accuracy: 0.5313 - val_loss: 0.6490 - val_accuracy: 0.6364
# Epoch 3/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.7061 - accuracy: 0.5654 - val_loss: 0.6319 - val_accuracy: 0.7175
# Epoch 4/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.6466 - accuracy: 0.6344 - val_loss: 0.6400 - val_accuracy: 0.6266
# Epoch 5/30
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6065 - accuracy: 0.6921 - val_loss: 0.6330 - val_accuracy: 0.6364
# Epoch 6/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6150 - accuracy: 0.6864 - val_loss: 0.5339 - val_accuracy: 0.7760
# Epoch 7/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5558 - accuracy: 0.7327 - val_loss: 0.5280 - val_accuracy: 0.7500
# Epoch 8/30
# 5/5 [==============================] - 1s 118ms/step - loss: 0.5125 - accuracy: 0.7587 - val_loss: 0.5565 - val_accuracy: 0.7273
# Epoch 9/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.4995 - accuracy: 0.7709 - val_loss: 0.5178 - val_accuracy: 0.7597
# Epoch 10/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4838 - accuracy: 0.7839 - val_loss: 0.5416 - val_accuracy: 0.7500
# Epoch 11/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4325 - accuracy: 0.8294 - val_loss: 0.5920 - val_accuracy: 0.7045
# Epoch 12/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4119 - accuracy: 0.8375 - val_loss: 0.5507 - val_accuracy: 0.7630
# Epoch 13/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3508 - accuracy: 0.8643 - val_loss: 0.7457 - val_accuracy: 0.6494
# Epoch 14/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.3770 - accuracy: 0.8513 - val_loss: 0.5241 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6049 - accuracy: 0.7135
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 64, 100)           806300
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 195ms/step - loss: 0.7480 - accuracy: 0.5232 - val_loss: 0.6767 - val_accuracy: 0.6494
# Epoch 2/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.7279 - accuracy: 0.5386 - val_loss: 0.6525 - val_accuracy: 0.6461
# Epoch 3/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6899 - accuracy: 0.5800 - val_loss: 0.6989 - val_accuracy: 0.5552
# Epoch 4/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6463 - accuracy: 0.6539 - val_loss: 0.5883 - val_accuracy: 0.6883
# Epoch 5/30
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6379 - accuracy: 0.6677 - val_loss: 0.5658 - val_accuracy: 0.7565
# Epoch 6/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5603 - accuracy: 0.7279 - val_loss: 0.6099 - val_accuracy: 0.6786
# Epoch 7/30
# 5/5 [==============================] - 0s 86ms/step - loss: 0.5423 - accuracy: 0.7490 - val_loss: 0.5461 - val_accuracy: 0.7630
# Epoch 8/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5310 - accuracy: 0.7612 - val_loss: 0.6224 - val_accuracy: 0.6948
# Epoch 9/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.4781 - accuracy: 0.7839 - val_loss: 0.5373 - val_accuracy: 0.7532
# Epoch 10/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4529 - accuracy: 0.8075 - val_loss: 0.5522 - val_accuracy: 0.7435
# Epoch 11/30
# 5/5 [==============================] - 0s 87ms/step - loss: 0.3835 - accuracy: 0.8546 - val_loss: 0.5494 - val_accuracy: 0.7468
# Epoch 12/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4717 - accuracy: 0.7977 - val_loss: 0.5331 - val_accuracy: 0.7662
# Epoch 13/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.3412 - accuracy: 0.8790 - val_loss: 0.5480 - val_accuracy: 0.7727
# Epoch 14/30
# 5/5 [==============================] - 0s 87ms/step - loss: 0.3872 - accuracy: 0.8400 - val_loss: 0.6078 - val_accuracy: 0.7403
# Epoch 15/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.3225 - accuracy: 0.8798 - val_loss: 0.5463 - val_accuracy: 0.7922
# Epoch 16/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2565 - accuracy: 0.9115 - val_loss: 0.5570 - val_accuracy: 0.7695
# Epoch 17/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3067 - accuracy: 0.8790 - val_loss: 0.5718 - val_accuracy: 0.7597
# 6/6 [==============================] - 1s 13ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6300 - accuracy: 0.7135
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 64, 100)           806300
#
#  lstm_3 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 268ms/step - loss: 0.7617 - accuracy: 0.5142 - val_loss: 0.6772 - val_accuracy: 0.5390
# Epoch 2/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7523 - accuracy: 0.5264 - val_loss: 0.6518 - val_accuracy: 0.6169
# Epoch 3/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.7235 - accuracy: 0.5394 - val_loss: 0.6330 - val_accuracy: 0.6364
# Epoch 4/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.6603 - accuracy: 0.6141 - val_loss: 0.7008 - val_accuracy: 0.5617
# Epoch 5/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6614 - accuracy: 0.6344 - val_loss: 0.5919 - val_accuracy: 0.6981
# Epoch 6/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6009 - accuracy: 0.6978 - val_loss: 0.5888 - val_accuracy: 0.6981
# Epoch 7/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.5618 - accuracy: 0.7157 - val_loss: 0.5804 - val_accuracy: 0.6981
# Epoch 8/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4865 - accuracy: 0.7839 - val_loss: 0.6345 - val_accuracy: 0.6688
# Epoch 9/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5001 - accuracy: 0.7831 - val_loss: 0.6573 - val_accuracy: 0.6883
# Epoch 10/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.4641 - accuracy: 0.8034 - val_loss: 0.5832 - val_accuracy: 0.7338
# Epoch 11/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4718 - accuracy: 0.7912 - val_loss: 0.5496 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.3980 - accuracy: 0.8473 - val_loss: 0.6505 - val_accuracy: 0.6851
# Epoch 13/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.3773 - accuracy: 0.8489 - val_loss: 0.5399 - val_accuracy: 0.7630
# Epoch 14/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3959 - accuracy: 0.8359 - val_loss: 0.5415 - val_accuracy: 0.7565
# Epoch 15/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2927 - accuracy: 0.8911 - val_loss: 0.5478 - val_accuracy: 0.7565
# Epoch 16/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2350 - accuracy: 0.9261 - val_loss: 0.8774 - val_accuracy: 0.6753
# Epoch 17/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3702 - accuracy: 0.8554 - val_loss: 0.5624 - val_accuracy: 0.7630
# Epoch 18/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1820 - accuracy: 0.9431 - val_loss: 0.6500 - val_accuracy: 0.7695
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8471 - accuracy: 0.6842
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 64, 100)           806300
#
#  lstm_4 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 186ms/step - loss: 0.7498 - accuracy: 0.5232 - val_loss: 0.6773 - val_accuracy: 0.5455
# Epoch 2/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.7215 - accuracy: 0.5475 - val_loss: 0.6648 - val_accuracy: 0.5552
# Epoch 3/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6563 - accuracy: 0.6206 - val_loss: 0.8778 - val_accuracy: 0.5097
# Epoch 4/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7080 - accuracy: 0.6296 - val_loss: 0.6175 - val_accuracy: 0.6558
# Epoch 5/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.5767 - accuracy: 0.7149 - val_loss: 0.5804 - val_accuracy: 0.6948
# Epoch 6/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5949 - accuracy: 0.7100 - val_loss: 0.5408 - val_accuracy: 0.7500
# Epoch 7/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.5182 - accuracy: 0.7628 - val_loss: 0.5305 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.5440 - accuracy: 0.7465 - val_loss: 0.5237 - val_accuracy: 0.7500
# Epoch 9/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4410 - accuracy: 0.8205 - val_loss: 0.5673 - val_accuracy: 0.7338
# Epoch 10/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.5176 - accuracy: 0.7701 - val_loss: 0.5403 - val_accuracy: 0.7565
# Epoch 11/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3947 - accuracy: 0.8392 - val_loss: 0.6095 - val_accuracy: 0.7143
# Epoch 12/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4395 - accuracy: 0.8140 - val_loss: 0.5476 - val_accuracy: 0.7565
# Epoch 13/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3413 - accuracy: 0.8733 - val_loss: 0.6933 - val_accuracy: 0.7013
# 6/6 [==============================] - 0s 12ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8559 - accuracy: 0.6199
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 64, 100)           806300
#
#  lstm_5 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 193ms/step - loss: 0.9235 - accuracy: 0.5199 - val_loss: 0.6863 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7359 - accuracy: 0.5321 - val_loss: 0.6692 - val_accuracy: 0.5877
# Epoch 3/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.7073 - accuracy: 0.5540 - val_loss: 0.6514 - val_accuracy: 0.6818
# Epoch 4/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.6856 - accuracy: 0.5890 - val_loss: 0.6362 - val_accuracy: 0.6721
# Epoch 5/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.6400 - accuracy: 0.6369 - val_loss: 0.7663 - val_accuracy: 0.5357
# Epoch 6/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.6379 - accuracy: 0.6613 - val_loss: 0.5842 - val_accuracy: 0.7013
# Epoch 7/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.5754 - accuracy: 0.6986 - val_loss: 0.5704 - val_accuracy: 0.7110
# Epoch 8/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5253 - accuracy: 0.7612 - val_loss: 0.7245 - val_accuracy: 0.6201
# Epoch 9/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.5432 - accuracy: 0.7490 - val_loss: 0.5836 - val_accuracy: 0.7110
# Epoch 10/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5037 - accuracy: 0.7660 - val_loss: 0.5497 - val_accuracy: 0.7435
# Epoch 11/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.4656 - accuracy: 0.7961 - val_loss: 0.5968 - val_accuracy: 0.7208
# Epoch 12/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4637 - accuracy: 0.8026 - val_loss: 0.5599 - val_accuracy: 0.7435
# Epoch 13/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.3890 - accuracy: 0.8416 - val_loss: 0.6009 - val_accuracy: 0.7078
# Epoch 14/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.4168 - accuracy: 0.8294 - val_loss: 0.6094 - val_accuracy: 0.7175
# Epoch 15/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3497 - accuracy: 0.8603 - val_loss: 0.5477 - val_accuracy: 0.7468
# Epoch 16/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.3034 - accuracy: 0.8895 - val_loss: 0.7394 - val_accuracy: 0.6753
# Epoch 17/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3990 - accuracy: 0.8310 - val_loss: 0.5531 - val_accuracy: 0.7435
# Epoch 18/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.2613 - accuracy: 0.9180 - val_loss: 0.5673 - val_accuracy: 0.7597
# Epoch 19/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.2314 - accuracy: 0.9277 - val_loss: 0.7017 - val_accuracy: 0.6883
# Epoch 20/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.2776 - accuracy: 0.8911 - val_loss: 0.5777 - val_accuracy: 0.7727
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7203 - accuracy: 0.6725
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 64, 100)           806300
#
#  lstm_6 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 186ms/step - loss: 0.8292 - accuracy: 0.5329 - val_loss: 0.6737 - val_accuracy: 0.6006
# Epoch 2/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7217 - accuracy: 0.5573 - val_loss: 0.6561 - val_accuracy: 0.6494
# Epoch 3/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.7084 - accuracy: 0.5719 - val_loss: 0.7038 - val_accuracy: 0.5292
# Epoch 4/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.6663 - accuracy: 0.6190 - val_loss: 0.6375 - val_accuracy: 0.6266
# Epoch 5/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6296 - accuracy: 0.6637 - val_loss: 0.6530 - val_accuracy: 0.6396
# Epoch 6/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.5917 - accuracy: 0.6913 - val_loss: 0.5445 - val_accuracy: 0.7370
# Epoch 7/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.5734 - accuracy: 0.7141 - val_loss: 0.5370 - val_accuracy: 0.7403
# Epoch 8/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.4750 - accuracy: 0.7880 - val_loss: 0.5585 - val_accuracy: 0.7305
# Epoch 9/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.5356 - accuracy: 0.7482 - val_loss: 0.5259 - val_accuracy: 0.7565
# Epoch 10/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4145 - accuracy: 0.8351 - val_loss: 0.5918 - val_accuracy: 0.7240
# Epoch 11/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4653 - accuracy: 0.8002 - val_loss: 0.5210 - val_accuracy: 0.7727
# Epoch 12/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.3372 - accuracy: 0.8725 - val_loss: 0.6169 - val_accuracy: 0.7110
# Epoch 13/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3920 - accuracy: 0.8359 - val_loss: 0.5376 - val_accuracy: 0.7662
# Epoch 14/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2759 - accuracy: 0.9041 - val_loss: 0.5415 - val_accuracy: 0.7857
# Epoch 15/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.2518 - accuracy: 0.9074 - val_loss: 0.8025 - val_accuracy: 0.6753
# Epoch 16/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3293 - accuracy: 0.8668 - val_loss: 0.6885 - val_accuracy: 0.7110
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 11ms/step - loss: 0.8944 - accuracy: 0.6667
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 64, 100)           806300
#
#  lstm_7 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 203ms/step - loss: 0.7903 - accuracy: 0.4866 - val_loss: 0.6751 - val_accuracy: 0.5584
# Epoch 2/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7515 - accuracy: 0.5524 - val_loss: 0.6331 - val_accuracy: 0.7078
# Epoch 3/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6946 - accuracy: 0.5955 - val_loss: 0.5759 - val_accuracy: 0.7370
# Epoch 4/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.7099 - accuracy: 0.5987 - val_loss: 0.5937 - val_accuracy: 0.6981
# Epoch 5/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.6081 - accuracy: 0.6848 - val_loss: 0.5815 - val_accuracy: 0.6981
# Epoch 6/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5850 - accuracy: 0.7100 - val_loss: 0.5424 - val_accuracy: 0.7532
# Epoch 7/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5509 - accuracy: 0.7474 - val_loss: 0.5446 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5247 - accuracy: 0.7514 - val_loss: 0.5352 - val_accuracy: 0.7435
# Epoch 9/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.5034 - accuracy: 0.7677 - val_loss: 0.5224 - val_accuracy: 0.7597
# Epoch 10/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4626 - accuracy: 0.7839 - val_loss: 0.5745 - val_accuracy: 0.7532
# Epoch 11/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4082 - accuracy: 0.8262 - val_loss: 0.5298 - val_accuracy: 0.7435
# Epoch 12/30
# 5/5 [==============================] - 1s 102ms/step - loss: 0.4140 - accuracy: 0.8197 - val_loss: 0.5338 - val_accuracy: 0.7760
# Epoch 13/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3586 - accuracy: 0.8562 - val_loss: 0.6176 - val_accuracy: 0.7403
# Epoch 14/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.3863 - accuracy: 0.8432 - val_loss: 0.5260 - val_accuracy: 0.7857
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6816 - accuracy: 0.6842
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 100)           806300
#
#  lstm_8 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 195ms/step - loss: 0.7874 - accuracy: 0.4898 - val_loss: 0.6649 - val_accuracy: 0.5682
# Epoch 2/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7141 - accuracy: 0.5735 - val_loss: 0.6230 - val_accuracy: 0.6656
# Epoch 3/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6235 - accuracy: 0.6596 - val_loss: 0.7440 - val_accuracy: 0.5877
# Epoch 4/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6276 - accuracy: 0.6832 - val_loss: 0.5896 - val_accuracy: 0.7045
# Epoch 5/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5630 - accuracy: 0.7206 - val_loss: 0.5343 - val_accuracy: 0.7468
# Epoch 6/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5880 - accuracy: 0.7108 - val_loss: 0.5305 - val_accuracy: 0.7500
# Epoch 7/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.5185 - accuracy: 0.7587 - val_loss: 0.5613 - val_accuracy: 0.7370
# Epoch 8/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5169 - accuracy: 0.7612 - val_loss: 0.6071 - val_accuracy: 0.6851
# Epoch 9/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4703 - accuracy: 0.7904 - val_loss: 0.5275 - val_accuracy: 0.7565
# Epoch 10/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4265 - accuracy: 0.8197 - val_loss: 0.5635 - val_accuracy: 0.7435
# Epoch 11/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.4236 - accuracy: 0.8050 - val_loss: 0.5520 - val_accuracy: 0.7468
# Epoch 12/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.3733 - accuracy: 0.8570 - val_loss: 0.5298 - val_accuracy: 0.7727
# Epoch 13/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3076 - accuracy: 0.8790 - val_loss: 0.7520 - val_accuracy: 0.6818
# Epoch 14/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.3985 - accuracy: 0.8408 - val_loss: 0.5465 - val_accuracy: 0.7695
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6766 - accuracy: 0.6608
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 64, 100)           806300
#
#  lstm_9 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 184ms/step - loss: 0.8432 - accuracy: 0.4882 - val_loss: 0.6972 - val_accuracy: 0.4805
# Epoch 2/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.7426 - accuracy: 0.5077 - val_loss: 0.6823 - val_accuracy: 0.5292
# Epoch 3/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.7135 - accuracy: 0.5491 - val_loss: 0.6540 - val_accuracy: 0.6494
# Epoch 4/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7341 - accuracy: 0.5719 - val_loss: 0.6811 - val_accuracy: 0.5584
# Epoch 5/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6550 - accuracy: 0.6255 - val_loss: 0.6223 - val_accuracy: 0.6688
# Epoch 6/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.6243 - accuracy: 0.6621 - val_loss: 0.5990 - val_accuracy: 0.6948
# Epoch 7/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.5765 - accuracy: 0.7157 - val_loss: 0.5605 - val_accuracy: 0.7208
# Epoch 8/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5450 - accuracy: 0.7392 - val_loss: 0.6829 - val_accuracy: 0.6364
# Epoch 9/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.5397 - accuracy: 0.7262 - val_loss: 0.5626 - val_accuracy: 0.7273
# Epoch 10/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4885 - accuracy: 0.7742 - val_loss: 0.6047 - val_accuracy: 0.6753
# Epoch 11/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.5076 - accuracy: 0.7652 - val_loss: 0.5623 - val_accuracy: 0.7370
# Epoch 12/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4711 - accuracy: 0.7994 - val_loss: 0.5452 - val_accuracy: 0.7338
# Epoch 13/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.3817 - accuracy: 0.8408 - val_loss: 0.5420 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4649 - accuracy: 0.7912 - val_loss: 0.5442 - val_accuracy: 0.7403
# Epoch 15/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3274 - accuracy: 0.8741 - val_loss: 0.5558 - val_accuracy: 0.7500
# Epoch 16/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4198 - accuracy: 0.8351 - val_loss: 0.5469 - val_accuracy: 0.7468
# Epoch 17/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3049 - accuracy: 0.8846 - val_loss: 0.8282 - val_accuracy: 0.6688
# Epoch 18/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.3382 - accuracy: 0.8806 - val_loss: 0.5713 - val_accuracy: 0.7532
# 6/6 [==============================] - 1s 9ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6386 - accuracy: 0.6959
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 64, 100)           806300
#
#  lstm_10 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 187ms/step - loss: 0.7506 - accuracy: 0.5004 - val_loss: 0.6813 - val_accuracy: 0.5552
# Epoch 2/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.7366 - accuracy: 0.5158 - val_loss: 0.6601 - val_accuracy: 0.6558
# Epoch 3/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6744 - accuracy: 0.6028 - val_loss: 0.7650 - val_accuracy: 0.5260
# Epoch 4/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.6493 - accuracy: 0.6556 - val_loss: 0.5938 - val_accuracy: 0.6948
# Epoch 5/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6166 - accuracy: 0.6653 - val_loss: 0.5564 - val_accuracy: 0.7305
# Epoch 6/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.6049 - accuracy: 0.7116 - val_loss: 0.5553 - val_accuracy: 0.7305
# Epoch 7/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5260 - accuracy: 0.7514 - val_loss: 0.5691 - val_accuracy: 0.7305
# Epoch 8/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5338 - accuracy: 0.7604 - val_loss: 0.5620 - val_accuracy: 0.7305
# Epoch 9/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5105 - accuracy: 0.7636 - val_loss: 0.5608 - val_accuracy: 0.7240
# Epoch 10/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4608 - accuracy: 0.8002 - val_loss: 0.7009 - val_accuracy: 0.6461
# Epoch 11/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.4936 - accuracy: 0.7823 - val_loss: 0.6577 - val_accuracy: 0.6786
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7871 - accuracy: 0.6257

# %%
print('accuracy:'+str(sum(score_list)/len(score_list)))
# Out:
# accuracy:0.6736842215061187

# %%
score_list.sort()

# %%
score_list
# Out:
# [0.6198830604553223,
#  0.6257309913635254,
#  0.6608186960220337,
#  0.6666666865348816,
#  0.6725146174430847,
#  0.6842105388641357,
#  0.6842105388641357,
#  0.6959064602851868,
#  0.7134503126144409,
#  0.7134503126144409]

# %%
sum(score_list[1:])/9
# Out:
# 0.6796621282895406
