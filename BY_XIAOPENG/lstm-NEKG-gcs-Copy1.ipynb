# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras_preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in swig_import_helper()
#      17         try:
# ---> 18             fp, pathname, description = imp.find_module('_pywrap_tensorflow_internal', [dirname(__file__)])
#      19         except ImportError:
#
# ~\anaconda3\lib\imp.py in find_module(name, path)
#     295     else:
# --> 296         raise ImportError(_ERR_MSG.format(name), name=name)
#     297
#
# ImportError: No module named '_pywrap_tensorflow_internal'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59   from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in swig_import_helper()
#      19         except ImportError:
# ---> 20             import _pywrap_tensorflow_internal
#      21             return _pywrap_tensorflow_internal
#
# ModuleNotFoundError: No module named '_pywrap_tensorflow_internal'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2760\2673336574.py in <module>
#       5 from sklearn import metrics
#       6 from sklearn.preprocessing import LabelEncoder,OneHotEncoder
# ----> 7 from keras.models import Model
#       8 from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
#       9 from keras.optimizers import RMSprop
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 20 from keras import distribute
#      21 from keras import models
#      22 from keras.engine.input_layer import Input
#
# ~\anaconda3\lib\site-packages\keras\distribute\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.distribute import sidecar_evaluator
#
# ~\anaconda3\lib\site-packages\keras\distribute\sidecar_evaluator.py in <module>
#      15 """Python module for evaluation loop."""
#      16
# ---> 17 import tensorflow.compat.v2 as tf
#      18
#      19 # isort: off
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25 # pylint: disable=wildcard-import
#      26 from tensorflow.tools.api.generator.api import *  # pylint: disable=redefined-builtin
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      47 import numpy as np
#      48
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      50
#      51 # Protocol buffers
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      72 for some common reasons and solutions.  Include the entire stack trace
#      73 above this error message when asking for help.""" % traceback.format_exc()
# ---> 74   raise ImportError(msg)
#      75
#      76 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\xwang\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 18, in swig_import_helper
#     fp, pathname, description = imp.find_module('_pywrap_tensorflow_internal', [dirname(__file__)])
#   File "C:\Users\xwang\anaconda3\lib\imp.py", line 296, in find_module
#     raise ImportError(_ERR_MSG.format(name), name=name)
# ImportError: No module named '_pywrap_tensorflow_internal'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xwang\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\xwang\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\xwang\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 20, in swig_import_helper
#     import _pywrap_tensorflow_internal
# ModuleNotFoundError: No module named '_pywrap_tensorflow_internal'
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/install_sources#common_installation_problems
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
pip uninstall tensorflow

# %%
install tensorflow

# %%
df = pd.read_csv("df_with_gcs_random_num.txt",sep=',',header=0)

# %%
#划分训练测试集
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# 处理词向量

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 切分词汇
def cut(data):
    cut= [s.split() for s in data['TriageNote'].astype(str)]
    return cut

# %%
train_text=cut(train_set)
test_text=cut(test_set)
sentences=train_text+test_text

# %%
#得到最大句子长度
num_list=[len(one) for one in sentences]
max(num_list)
# Out:
# 57

# %%
maxLen=64

# %%
#处理label->one_hot
from sklearn.preprocessing import LabelEncoder

def encodelabel(data):
    le = LabelEncoder()
    resultLable=le.fit_transform(data['DISPOSITION'])
    return resultLable

# %%
train_lable=encodelabel(train_set)
test_lable=encodelabel(test_set)

# %%
wvmodel = word2vec.Word2Vec.load("./word2vec/word2vec_all.model")
# Out:
# 2022-09-26 14:41:38,467 : INFO : loading Word2Vec object from ./word2vec/word2vec_all.model
# 2022-09-26 14:41:38,478 : INFO : loading wv recursively from ./word2vec/word2vec_all.model.wv.* with mmap=None
# 2022-09-26 14:41:38,478 : INFO : setting ignored attribute cum_table to None
# 2022-09-26 14:41:38,599 : INFO : Word2Vec lifecycle event {'fname': './word2vec/word2vec_all.model', 'datetime': '2022-09-26T14:41:38.599599', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'loaded'}

# %%
nekg=np.load('nekg 1-999 100d.npy')

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab = tokenizer.word_index

# %%
#特征数字编号，不足的话会在前面补充0
trainID = tokenizer.texts_to_sequences(train_text)
# print(trainID)
testID = tokenizer.texts_to_sequences(test_text)
trainSeq=pad_sequences(trainID,maxlen=maxLen)
#print(trainSeq)
testSeq=pad_sequences(testID,maxlen=maxLen)

#标签的独热编码
trainCate = to_categorical(train_lable, num_classes=2)  # 将标签转换为one-hot编码
#print(trainCate)
testCate= to_categorical(test_lable, num_classes=2)  # 将标签转换为one-hot编码

# %%
def nekg_embed(n0):
    n1=int(n0)
    n2=int(n0)+1
    s1=(n2-n0)/(n2-n1)
    s2=(n0-n1)/(n2-n1)
    return s1*nekg[n1]+s2*nekg[n2]

# %%
#利用训练后的word2vec自定义Embedding的训练矩阵，每行代表一个词（结合独热码和矩阵乘法理解）
embedding_matrix = np.zeros((len(vocab) + 1, 100))
for word, i in vocab.items():
    try:
        if(word.isdigit()==False):#对word用word2vec
            embedding_vector = wvmodel.wv[str(word)]
        else:#对number用nekg
            if (int(float(word))<=998):
                embedding_vector =  nekg_embed(float(word))
            else:
                embedding_vector = wvmodel.wv[str(word)]
        embedding_matrix[i] = embedding_vector    
    except KeyError:
        continue

# %%
## 定义LSTM模型
batch_size=256
inputs = Input(name='inputs',shape=[maxLen])
embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
model=Sequential()
model.add(embedder)
model.add(LSTM(64))
model.add(Dense(64,activation="sigmoid",name="FC1"))
model.add(Dropout(0.4))
model.add(Dense(2,activation="softmax",name="FC2"))
model.summary()
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
#reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
model.save("LSTM")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 64, 100)           775100
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 208ms/step - loss: 0.7883 - accuracy: 0.4842 - val_loss: 0.6820 - val_accuracy: 0.5455
# Epoch 2/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.7302 - accuracy: 0.5264 - val_loss: 0.6812 - val_accuracy: 0.4903
# Epoch 3/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.7178 - accuracy: 0.5597 - val_loss: 0.6269 - val_accuracy: 0.6494
# Epoch 4/30
# 5/5 [==============================] - 0s 99ms/step - loss: 0.6570 - accuracy: 0.6271 - val_loss: 0.5809 - val_accuracy: 0.7143
# Epoch 5/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6218 - accuracy: 0.6637 - val_loss: 0.5558 - val_accuracy: 0.7468
# Epoch 6/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.5760 - accuracy: 0.7222 - val_loss: 0.5900 - val_accuracy: 0.6851
# Epoch 7/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.5655 - accuracy: 0.7141 - val_loss: 0.5455 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5041 - accuracy: 0.7717 - val_loss: 0.7172 - val_accuracy: 0.6623
# Epoch 9/30
# 5/5 [==============================] - 1s 99ms/step - loss: 0.5455 - accuracy: 0.7474 - val_loss: 0.5325 - val_accuracy: 0.7695
# Epoch 10/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.4763 - accuracy: 0.7888 - val_loss: 0.5402 - val_accuracy: 0.7532
# Epoch 11/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4531 - accuracy: 0.8042 - val_loss: 0.5433 - val_accuracy: 0.7532
# Epoch 12/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4328 - accuracy: 0.8140 - val_loss: 0.5426 - val_accuracy: 0.7532
# Epoch 13/30
# 5/5 [==============================] - 1s 116ms/step - loss: 0.4084 - accuracy: 0.8343 - val_loss: 0.5385 - val_accuracy: 0.7662
# Epoch 14/30
# 5/5 [==============================] - 1s 116ms/step - loss: 0.3624 - accuracy: 0.8530 - val_loss: 0.5818 - val_accuracy: 0.7435
# 2022-09-26 14:41:50,856 : WARNING : Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM\assets
# 2022-09-26 14:41:51,403 : INFO : Assets written to: LSTM\assets

# %%
#预测与评估
mainModel = load_model('LSTM')
result = mainModel.predict(testSeq)  # 预测样本属于每个类别的概率
score = mainModel.evaluate(testSeq,
                           testCate,
                           batch_size=32)
print(score)
# Out:
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7389 - accuracy: 0.6550
# [0.7389013171195984, 0.6549707651138306]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

# %%
score_list=[]
for i in range(10):
    ## 定义LSTM模型
    batch_size=256
    inputs = Input(name='inputs',shape=[maxLen])
    embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
    model=Sequential()
    model.add(embedder)
    model.add(LSTM(64))
    model.add(Dense(64,activation="sigmoid",name="FC1"))
    model.add(Dropout(0.4,seed=12))
    model.add(Dense(2,activation="softmax",name="FC2"))
    model.summary()
    model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
    history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
    result = model.predict(testSeq)  # 预测样本属于每个类别的概率
    score = model.evaluate(testSeq,
                               testCate,
                               batch_size=32)
    score_list.append(score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 64, 100)           775100
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 203ms/step - loss: 0.7648 - accuracy: 0.4898 - val_loss: 0.6802 - val_accuracy: 0.6461
# Epoch 2/30
# 5/5 [==============================] - 0s 84ms/step - loss: 0.7397 - accuracy: 0.5069 - val_loss: 0.6508 - val_accuracy: 0.6753
# Epoch 3/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.7181 - accuracy: 0.5646 - val_loss: 0.6487 - val_accuracy: 0.6071
# Epoch 4/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.6483 - accuracy: 0.6385 - val_loss: 0.5685 - val_accuracy: 0.7500
# Epoch 5/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.6243 - accuracy: 0.6669 - val_loss: 0.5666 - val_accuracy: 0.7175
# Epoch 6/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.5838 - accuracy: 0.7043 - val_loss: 0.5723 - val_accuracy: 0.7240
# Epoch 7/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.5553 - accuracy: 0.7303 - val_loss: 0.5794 - val_accuracy: 0.6916
# Epoch 8/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.4997 - accuracy: 0.7693 - val_loss: 0.5454 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.5401 - accuracy: 0.7571 - val_loss: 0.5356 - val_accuracy: 0.7565
# Epoch 10/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4818 - accuracy: 0.8058 - val_loss: 0.5350 - val_accuracy: 0.7565
# Epoch 11/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.3927 - accuracy: 0.8343 - val_loss: 0.5530 - val_accuracy: 0.7727
# Epoch 12/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.4626 - accuracy: 0.8002 - val_loss: 0.5509 - val_accuracy: 0.7435
# Epoch 13/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3669 - accuracy: 0.8554 - val_loss: 0.5716 - val_accuracy: 0.7500
# Epoch 14/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.3428 - accuracy: 0.8733 - val_loss: 0.5582 - val_accuracy: 0.7857
# Epoch 15/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.3090 - accuracy: 0.8871 - val_loss: 0.8153 - val_accuracy: 0.6266
# 6/6 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7902 - accuracy: 0.6491
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 64, 100)           775100
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 182ms/step - loss: 0.7723 - accuracy: 0.4996 - val_loss: 0.6766 - val_accuracy: 0.6558
# Epoch 2/30
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7321 - accuracy: 0.5329 - val_loss: 0.6458 - val_accuracy: 0.6818
# Epoch 3/30
# 5/5 [==============================] - 1s 100ms/step - loss: 0.7128 - accuracy: 0.5833 - val_loss: 0.6097 - val_accuracy: 0.6623
# Epoch 4/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.6728 - accuracy: 0.6190 - val_loss: 0.5925 - val_accuracy: 0.7078
# Epoch 5/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6346 - accuracy: 0.6572 - val_loss: 0.5565 - val_accuracy: 0.7468
# Epoch 6/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6573 - accuracy: 0.6742 - val_loss: 0.5620 - val_accuracy: 0.7208
# Epoch 7/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5537 - accuracy: 0.7352 - val_loss: 0.6468 - val_accuracy: 0.6656
# Epoch 8/30
# 5/5 [==============================] - 1s 119ms/step - loss: 0.5387 - accuracy: 0.7441 - val_loss: 0.5365 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4743 - accuracy: 0.7766 - val_loss: 0.6823 - val_accuracy: 0.6558
# Epoch 10/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4917 - accuracy: 0.7758 - val_loss: 0.5865 - val_accuracy: 0.7240
# Epoch 11/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.4512 - accuracy: 0.8091 - val_loss: 0.5387 - val_accuracy: 0.7532
# Epoch 12/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4724 - accuracy: 0.7904 - val_loss: 0.5332 - val_accuracy: 0.7662
# Epoch 13/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3739 - accuracy: 0.8546 - val_loss: 0.5464 - val_accuracy: 0.7792
# Epoch 14/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3854 - accuracy: 0.8375 - val_loss: 0.5983 - val_accuracy: 0.7338
# Epoch 15/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.3516 - accuracy: 0.8635 - val_loss: 0.5557 - val_accuracy: 0.7695
# Epoch 16/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3614 - accuracy: 0.8635 - val_loss: 0.5534 - val_accuracy: 0.7760
# Epoch 17/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2765 - accuracy: 0.9009 - val_loss: 0.7617 - val_accuracy: 0.6948
# 6/6 [==============================] - 0s 7ms/step
# 6/6 [==============================] - 0s 5ms/step - loss: 0.9701 - accuracy: 0.6374
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 64, 100)           775100
#
#  lstm_3 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s
(LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 216ms/step - loss: 0.7897 - accuracy: 0.5199 - val_loss: 0.6709 - val_accuracy: 0.6299
# Epoch 2/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.7308 - accuracy: 0.5248 - val_loss: 0.6767 - val_accuracy: 0.5357
# Epoch 3/30
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6875 - accuracy: 0.5833 - val_loss: 0.6502 - val_accuracy: 0.5942
# Epoch 4/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.6685 - accuracy: 0.5979 - val_loss: 0.5950 - val_accuracy: 0.7208
# Epoch 5/30
# 5/5 [==============================] - 1s 146ms/step - loss: 0.6187 - accuracy: 0.6742 - val_loss: 0.7170 - val_accuracy: 0.5584
# Epoch 6/30
# 5/5 [==============================] - 1s 154ms/step - loss: 0.6135 - accuracy: 0.6767 - val_loss: 0.5718 - val_accuracy: 0.7110
# Epoch 7/30
# 5/5 [==============================] - 1s 152ms/step - loss: 0.5639 - accuracy: 0.7303 - val_loss: 0.6283 - val_accuracy: 0.6721
# Epoch 8/30
# 5/5 [==============================] - 1s 150ms/step - loss: 0.5448 - accuracy: 0.7376 - val_loss: 0.5878 - val_accuracy: 0.7045
# Epoch 9/30
# 5/5 [==============================] - 1s 147ms/step - loss: 0.5423 - accuracy: 0.7344 - val_loss: 0.5517 - val_accuracy: 0.7403
# Epoch 10/30
# 5/5 [==============================] - 1s 151ms/step - loss: 0.4592 - accuracy: 0.8075 - val_loss: 0.5412 - val_accuracy: 0.7305
# Epoch 11/30
# 5/5 [==============================] - 1s 153ms/step - loss: 0.4822 - accuracy: 0.7807 - val_loss: 0.5928 - val_accuracy: 0.7078
# Epoch 12/30
# 5/5 [==============================] - 1s 148ms/step - loss: 0.4101 - accuracy: 0.8327 - val_loss: 0.5367 - val_accuracy: 0.7532
# Epoch 13/30
# 5/5 [==============================] - 1s 158ms/step - loss: 0.4263 - accuracy: 0.8156 - val_loss: 0.5315 - val_accuracy: 0.7338
# Epoch 14/30
# 5/5 [==============================] - 1s 165ms/step - loss: 0.3867 - accuracy: 0.8538 - val_loss: 0.6999 - val_accuracy: 0.6753
# Epoch 15/30
# 5/5 [==============================] - 1s 156ms/step - loss: 0.3852 - accuracy: 0.8457 - val_loss: 0.5376 - val_accuracy: 0.7630
# Epoch 16/30
# 5/5 [==============================] - 1s 160ms/step - loss: 0.2767 - accuracy: 0.8952 - val_loss: 0.8357 - val_accuracy: 0.6234
# Epoch 17/30
# 5/5 [==============================] - 1s 149ms/step - loss: 0.3553 - accuracy: 0.8570 - val_loss: 0.5439 - val_accuracy: 0.7727
# Epoch 18/30
# 5/5 [==============================] - 1s 155ms/step - loss: 0.2345 - accuracy: 0.9212 - val_loss: 0.6588 - val_accuracy: 0.7240
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7316 - accuracy: 0.6550
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 64, 100)           775100
#
#  lstm_7 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 193ms/step - loss: 0.7698 - accuracy: 0.5126 - val_loss: 0.6831 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 1s 114ms/step - loss: 0.7220 - accuracy: 0.5435 - val_loss: 0.6680 - val_accuracy: 0.6039
# Epoch 3/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.7055 - accuracy: 0.5589 - val_loss: 0.7062 - val_accuracy: 0.5065
# Epoch 4/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.6782 - accuracy: 0.5922 - val_loss: 0.5822 - val_accuracy: 0.7175
# Epoch 5/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.6452 - accuracy: 0.6450 - val_loss: 0.5931 - val_accuracy: 0.6818
# Epoch 6/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.6120 - accuracy: 0.6791 - val_loss: 0.5785 - val_accuracy: 0.7273
# Epoch 7/30
# 5/5 [==============================] - 1s 121ms/step - loss: 0.5401 - accuracy: 0.7368 - val_loss: 0.5452 - val_accuracy: 0.7435
# Epoch 8/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.5494 - accuracy: 0.7482 - val_loss: 0.5418 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5113 - accuracy: 0.7652 - val_loss: 0.6706 - val_accuracy: 0.6623
# Epoch 10/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4834 - accuracy: 0.7734 - val_loss: 0.5656 - val_accuracy: 0.7468
# Epoch 11/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4574 - accuracy: 0.8091 - val_loss: 0.5298 - val_accuracy: 0.7532
# Epoch 12/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4500 - accuracy: 0.8148 - val_loss: 0.6148 - val_accuracy: 0.6883
# Epoch 13/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.3970 - accuracy: 0.8286 - val_loss: 0.5340 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.4181 - accuracy: 0.8197 - val_loss: 0.5563 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 1s 135ms/step - loss: 0.3337 - accuracy: 0.8643 - val_loss: 0.6123 - val_accuracy: 0.7175
# Epoch 16/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.3287 - accuracy: 0.8773 - val_loss: 0.5417 - val_accuracy: 0.7695
# 6/6 [==============================] - 0s 7ms/step
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6206 - accuracy: 0.6901
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 100)           775100
#
#  lstm_8 (LSTM)               (None, 64)                42240
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 185ms/step - loss: 0.7539 - accuracy: 0.5207 - val_loss: 0.6818 - val_accuracy: 0.5292
# Epoch 2/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.7193 - accuracy: 0.5670 - val_loss: 0.6523 - val_accuracy: 0.6071
# Epoch 3/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.7036 - accuracy: 0.5808 - val_loss: 0.6173 - val_accuracy: 0.6591
# Epoch 4/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.6852 - accuracy: 0.5881 - val_loss: 0.5768 - val_accuracy: 0.7110
# Epoch 5/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.5899 - accuracy: 0.6946 - val_loss: 0.6875 - val_accuracy: 0.6299
# Epoch 6/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.5955 - accuracy: 0.7059 - val_loss: 0.5622 - val_accuracy: 0.7273
# Epoch 7/30
# 5/5 [==============================] - 1s 122ms/step - loss: 0.5699 - accuracy: 0.7165 - val_loss: 0.5568 - val_accuracy: 0.7110
# Epoch 8/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.5310 - accuracy: 0.7579 - val_loss: 0.5349 - val_accuracy: 0.7403
# Epoch 9/30
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4922 - accuracy: 0.7774 - val_loss: 0.5270 - val_accuracy: 0.7403
# Epoch 10/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4544 - accuracy: 0.8091 - val_loss: 0.6550 - val_accuracy: 0.6851
# Epoch 11/30
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4671 - accuracy: 0.7985 - val_loss: 0.5400 - val_accuracy: 0.7630
# Epoch 12/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.3871 - accuracy: 0.8400 - val_loss: 0.5659 - val_accuracy: 0.7435
# Epoch 13/30
# 5/5 [==============================] - 1s 124ms/step - loss: 0.3567 - accuracy: 0.8587 - val_loss: 0.6348 - val_accuracy: 0.7240
# Epoch 14/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4156 - accuracy: 0.8213 - val_loss: 0.5589 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 7ms/step
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6535 - accuracy: 0.6959
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 64, 100)           775100
#
#  lstm_9 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 243ms/step - loss: 0.7610 - accuracy: 0.5142 - val_loss: 0.6753 - val_accuracy: 0.6266
# Epoch 2/30
# 5/5 [==============================] - 1s 148ms/step - loss: 0.7295 - accuracy: 0.5264 - val_loss: 0.6467 - val_accuracy: 0.6494
# Epoch 3/30
# 5/5 [==============================] - 1s 179ms/step - loss: 0.7069 - accuracy: 0.5678 - val_loss: 0.6316 - val_accuracy: 0.6526
# Epoch 4/30
# 5/5 [==============================] - 1s 156ms/step - loss: 0.6561 - accuracy: 0.6369 - val_loss: 0.6054 - val_accuracy: 0.6916
# Epoch 5/30
# 5/5 [==============================] - 1s 171ms/step - loss: 0.5930 - accuracy: 0.6775 - val_loss: 0.5395 - val_accuracy: 0.7597
# Epoch 6/30
# 5/5 [==============================] - 1s 162ms/step - loss: 0.6208 - accuracy: 0.6954 - val_loss: 0.5455 - val_accuracy: 0.7435
# Epoch 7/30
# 5/5 [==============================] - 1s 176ms/step - loss: 0.5439 - accuracy: 0.7441 - val_loss: 0.5497 - val_accuracy: 0.7305
# Epoch 8/30
# 5/5 [==============================] - 1s 154ms/step - loss: 0.4871 - accuracy: 0.7815 - val_loss: 0.5605 - val_accuracy: 0.7370
# Epoch 9/30
# 5/5 [==============================] - 1s 181ms/step - loss: 0.5368 - accuracy: 0.7669 - val_loss: 0.5257 - val_accuracy: 0.7857
# Epoch 10/30
# 5/5 [==============================] - 1s 165ms/step - loss: 0.4689 - accuracy: 0.8123 - val_loss: 0.5261 - val_accuracy: 0.7370
# Epoch 11/30
# 5/5 [==============================] - 1s 171ms/step - loss: 0.3951 - accuracy: 0.8432 - val_loss: 0.6392 - val_accuracy: 0.6851
# Epoch 12/30
# 5/5 [==============================] - 1s 161ms/step - loss: 0.4388 - accuracy: 0.8034 - val_loss: 0.5273 - val_accuracy: 0.7825
# Epoch 13/30
# 5/5 [==============================] - 1s 159ms/step - loss: 0.3747 - accuracy: 0.8513 - val_loss: 0.5575 - val_accuracy: 0.7370
# Epoch 14/30
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3316 - accuracy: 0.8781 - val_loss: 0.5768 - val_accuracy: 0.7370
# 6/6 [==============================] - 0s 8ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6454 - accuracy: 0.6784
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 64, 100)           775100
#
#  lstm_10 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 821,630
# Trainable params: 821,630
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 213ms/step - loss: 0.9366 - accuracy: 0.4760 - val_loss: 0.7042 - val_accuracy: 0.4253
# Epoch 2/30
# 5/5 [==============================] - 1s 147ms/step - loss: 0.7405 - accuracy: 0.5183 - val_loss: 0.6876 - val_accuracy: 0.5162
# Epoch 3/30
# 5/5 [==============================] - 1s 136ms/step - loss: 0.7450 - accuracy: 0.5134 - val_loss: 0.6850 - val_accuracy: 0.5260
# Epoch 4/30
# 5/5 [==============================] - 1s 162ms/step - loss: 0.7189 - accuracy: 0.5248 - val_loss: 0.6312 - val_accuracy: 0.6786
# Epoch 5/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.6989 - accuracy: 0.5792 - val_loss: 0.6361 - val_accuracy: 0.7208
# Epoch 6/30
# 5/5 [==============================] - 1s 150ms/step - loss: 0.6219 - accuracy: 0.6458 - val_loss: 0.6706 - val_accuracy: 0.5779
# Epoch 7/30
# 5/5 [==============================] - 1s 147ms/step - loss: 0.6631 - accuracy: 0.6596 - val_loss: 0.5998 - val_accuracy: 0.6753
# Epoch 8/30
# 5/5 [==============================] - 1s 139ms/step - loss: 0.5692 - accuracy: 0.7100 - val_loss: 0.5363 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 139ms/step - loss: 0.5815 - accuracy: 0.7116 - val_loss: 0.5624 - val_accuracy: 0.7175
# Epoch 10/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.5200 - accuracy: 0.7612 - val_loss: 0.5986 - val_accuracy: 0.6656
# Epoch 11/30
# 5/5 [==============================] - 1s 146ms/step - loss: 0.4635 - accuracy: 0.8034 - val_loss: 0.5344 - val_accuracy: 0.7565
# Epoch 12/30
# 5/5 [==============================] - 1s 147ms/step - loss: 0.5172 - accuracy: 0.7669 - val_loss: 0.5282 - val_accuracy: 0.7468
# Epoch 13/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.4414 - accuracy: 0.8197 - val_loss: 0.7221 - val_accuracy: 0.6039
# Epoch 14/30
# 5/5 [==============================] - 1s 142ms/step - loss: 0.4368 - accuracy: 0.8123 - val_loss: 0.5228 - val_accuracy: 0.7825
# Epoch 15/30
# 5/5 [==============================] - 1s 145ms/step - loss: 0.4144 - accuracy: 0.8367 - val_loss: 0.5487 - val_accuracy: 0.7565
# Epoch 16/30
# 5/5 [==============================] - 1s 140ms/step - loss: 0.3367 - accuracy: 0.8700 - val_loss: 0.6479 - val_accuracy: 0.6786
# Epoch 17/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.3655 - accuracy: 0.8473 - val_loss: 0.6554 - val_accuracy: 0.6981
# Epoch 18/30
# 5/5 [==============================] - 1s 139ms/step - loss: 0.2756 - accuracy: 0.9058 - val_loss: 0.5590 - val_accuracy: 0.7630
# Epoch 19/30
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3508 - accuracy: 0.8700 - val_loss: 0.5771 - val_accuracy: 0.7143
# 6/6 [==============================] - 0s 12ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6366 - accuracy: 0.6725

# %%
print('accuracy:'+str(sum(score_list)/len(score_list)))
# Out:
# accuracy:0.6748538017272949

# %%
score_list.sort()

# %%
score_list
# Out:
# [0.6374269127845764,
#  0.6491228342056274,
#  0.6549707651138306,
#  0.6725146174430847,
#  0.6783625483512878,
#  0.6783625483512878,
#  0.6900584697723389,
#  0.6900584697723389,
#  0.6959064602851868,
#  0.7017543911933899]
