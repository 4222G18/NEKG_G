# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras_preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
# %matplotlib inline

# %%
# pip uninstall tensorflow

# %%
# install tensorflow

# %%
df = pd.read_csv("df_with_gcs.txt",sep=',',header=0)

# %%
#划分训练测试集
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %% [markdown]
# 处理词向量

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 切分词汇
def cut(data):
    cut= [s.split() for s in data['TriageNote'].astype(str)]
    return cut

# %%
train_text=cut(train_set)
test_text=cut(test_set)
sentences=train_text+test_text

# %%
#得到最大句子长度
num_list=[len(one) for one in sentences]
max(num_list)
# Out:
# 57

# %%
maxLen=64

# %%
#处理label->one_hot
from sklearn.preprocessing import LabelEncoder

def encodelabel(data):
    le = LabelEncoder()
    resultLable=le.fit_transform(data['DISPOSITION'])
    return resultLable

# %%
train_lable=encodelabel(train_set)
test_lable=encodelabel(test_set)

# %%
wvmodel = word2vec.Word2Vec.load("./word2vec_all.model")
# Out:
# 2022-11-09 02:38:39,328 : INFO : loading Word2Vec object from ./word2vec_all.model
# 2022-11-09 02:38:39,409 : INFO : loading wv recursively from ./word2vec_all.model.wv.* with mmap=None
# 2022-11-09 02:38:39,410 : INFO : setting ignored attribute cum_table to None
# 2022-11-09 02:38:39,509 : INFO : Word2Vec lifecycle event {'fname': './word2vec_all.model', 'datetime': '2022-11-09T02:38:39.507756', 'gensim': '4.2.0', 'python': '3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]', 'platform': 'Linux-5.15.68.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'loaded'}

# %%
nekg=np.load('nekg 1-999 100d.npy')
nekg
# Out:
# array([[-0.03946331, -0.02480048,  0.06082289, ..., -0.01568387,
#          0.05039275,  0.03724619],
#        [-0.03825712, -0.02397725,  0.05963894, ..., -0.01502065,
#          0.05186065,  0.03724643],
#        [-0.03705093, -0.02315403,  0.05845498, ..., -0.01435742,
#          0.05332854,  0.03724668],
#        ...,
#        [ 0.06336232, -0.04929246, -0.02796983, ...,  0.03513284,
#         -0.04742226,  0.04023478],
#        [ 0.06356958, -0.04936811, -0.02988294, ...,  0.03573058,
#         -0.04924951,  0.03923785],
#        [ 0.06377684, -0.04944375, -0.03179605, ...,  0.03632831,
#         -0.05107678,  0.03824091]])

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
vocab = tokenizer.word_index

# %%
#特征数字编号，不足的话会在前面补充0
trainID = tokenizer.texts_to_sequences(train_text)
# print(trainID)
testID = tokenizer.texts_to_sequences(test_text)
trainSeq=pad_sequences(trainID,maxlen=maxLen)
#print(trainSeq)
testSeq=pad_sequences(testID,maxlen=maxLen)

#标签的独热编码
trainCate = to_categorical(train_lable, num_classes=2)  # 将标签转换为one-hot编码
#print(trainCate)
testCate= to_categorical(test_lable, num_classes=2)  # 将标签转换为one-hot编码

# %%
def nekg_embed(n0):
    n1=int(n0)
    n2=int(n0)+1
    s1=(n2-n0)/(n2-n1)
    s2=(n0-n1)/(n2-n1)
    return s1*nekg[n1]+s2*nekg[n2]

# %%
#利用训练后的word2vec自定义Embedding的训练矩阵，每行代表一个词（结合独热码和矩阵乘法理解）
embedding_matrix = np.zeros((len(vocab) + 1, 100))
for word, i in vocab.items():
    try:
        if(word.isdigit()==False):#对word用word2vec
            embedding_vector = wvmodel.wv[str(word)]
        else:#对number用nekg
            if (int(float(word))<=998):
                embedding_vector =  nekg_embed(float(word))
            else:
                embedding_vector = wvmodel.wv[str(word)]
        embedding_matrix[i] = embedding_vector    
    except KeyError:
        continue

# %%
## 定义LSTM模型
batch_size=256
inputs = Input(name='inputs',shape=[maxLen])
embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
model=Sequential()
model.add(embedder)
model.add(LSTM(64))
model.add(Dense(64,activation="sigmoid",name="FC1"))
model.add(Dropout(0.4))
model.add(Dense(2,activation="softmax",name="FC2"))
model.summary()
model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
#reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
model.save("LSTM")
# Out:
# 2022-11-09 02:38:40.517919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-11-09 02:38:40.791244: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.8/lib64
# 2022-11-09 02:38:40.791316: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-09 02:38:40.812547: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 64, 100)           806300
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 4s 357ms/step - loss: 0.7911 - accuracy: 0.4915 - val_loss: 0.6828 - val_accuracy: 0.5455
# Epoch 2/30
# 5/5 [==============================] - 1s 117ms/step - loss: 0.7538 - accuracy: 0.5215 - val_loss: 0.6674 - val_accuracy: 0.6786
# Epoch 3/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.7052 - accuracy: 0.5662 - val_loss: 0.6294 - val_accuracy: 0.6883
# Epoch 4/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7114 - accuracy: 0.5963 - val_loss: 0.5978 - val_accuracy: 0.7403
# Epoch 5/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6126 - accuracy: 0.6742 - val_loss: 0.6489 - val_accuracy: 0.6656
# Epoch 6/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6291 - accuracy: 0.6751 - val_loss: 0.6300 - val_accuracy: 0.6429
# Epoch 7/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5567 - accuracy: 0.7189 - val_loss: 0.5792 - val_accuracy: 0.6916
# Epoch 8/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.5387 - accuracy: 0.7457 - val_loss: 0.5631 - val_accuracy: 0.7175
# Epoch 9/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.5229 - accuracy: 0.7474 - val_loss: 0.5508 - val_accuracy: 0.7370
# Epoch 10/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4488 - accuracy: 0.8180 - val_loss: 0.5777 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4436 - accuracy: 0.8010 - val_loss: 0.5291 - val_accuracy: 0.7760
# Epoch 12/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.4278 - accuracy: 0.8278 - val_loss: 0.5248 - val_accuracy: 0.7630
# Epoch 13/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.3507 - accuracy: 0.8554 - val_loss: 0.6055 - val_accuracy: 0.7175
# Epoch 14/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3403 - accuracy: 0.8603 - val_loss: 0.5743 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2831 - accuracy: 0.9090 - val_loss: 0.5624 - val_accuracy: 0.7727
# Epoch 16/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3778 - accuracy: 0.8505 - val_loss: 0.5261 - val_accuracy: 0.7857
# Epoch 17/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2163 - accuracy: 0.9285 - val_loss: 0.6107 - val_accuracy: 0.7500
# 2022-11-09 02:38:58,187 : WARNING : Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM/assets
# 2022-11-09 02:38:59,449 : INFO : Assets written to: LSTM/assets

# %%
#预测与评估
mainModel = load_model('LSTM')
result = mainModel.predict(testSeq)  # 预测样本属于每个类别的概率
score = mainModel.evaluate(testSeq,
                           testCate,
                           batch_size=32)
print(score)
# Out:
# 6/6 [==============================] - 1s 12ms/step
# 6/6 [==============================] - 1s 16ms/step - loss: 0.6430 - accuracy: 0.7251
# [0.6430004835128784, 0.7251461744308472]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Valid'],loc='upper left')
plt.show()

# %%
score_list=[]
for i in range(10):
    ## 定义LSTM模型
    batch_size=256
    inputs = Input(name='inputs',shape=[maxLen])
    embedder = Embedding(len(vocab) + 1, 100, input_length=maxLen, weights=[embedding_matrix], trainable=True)
    model=Sequential()
    model.add(embedder)
    model.add(LSTM(64))
    model.add(Dense(64,activation="sigmoid",name="FC1"))
    model.add(Dropout(0.4,seed=12))
    model.add(Dense(2,activation="softmax",name="FC2"))
    model.summary()
    model.compile(loss="categorical_crossentropy",optimizer=RMSprop(),metrics=["accuracy"])
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.1 ,patience=3, mode='auto')
    history=model.fit(trainSeq, trainCate, batch_size, epochs=30,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss',patience=5)])
    result = model.predict(testSeq)  # 预测样本属于每个类别的概率
    score = model.evaluate(testSeq,
                               testCate,
                               batch_size=32)
    score_list.append(score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 64, 100)           806300
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 203ms/step - loss: 0.7736 - accuracy: 0.4980 - val_loss: 0.6848 - val_accuracy: 0.5487
# Epoch 2/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.7275 - accuracy: 0.5516 - val_loss: 0.6588 - val_accuracy: 0.5974
# Epoch 3/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7203 - accuracy: 0.5565 - val_loss: 0.6846 - val_accuracy: 0.5097
# Epoch 4/30
# 5/5 [==============================] - 0s 104ms/step - loss: 0.6691 - accuracy: 0.6003 - val_loss: 0.5728 - val_accuracy: 0.7305
# Epoch 5/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6632 - accuracy: 0.6507 - val_loss: 0.5876 - val_accuracy: 0.6883
# Epoch 6/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.6013 - accuracy: 0.6775 - val_loss: 0.5587 - val_accuracy: 0.7240
# Epoch 7/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6030 - accuracy: 0.6946 - val_loss: 0.5415 - val_accuracy: 0.7500
# Epoch 8/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5108 - accuracy: 0.7742 - val_loss: 0.5653 - val_accuracy: 0.7078
# Epoch 9/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.5659 - accuracy: 0.7246 - val_loss: 0.5733 - val_accuracy: 0.7273
# Epoch 10/30
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5027 - accuracy: 0.7636 - val_loss: 0.5295 - val_accuracy: 0.7500
# Epoch 11/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4873 - accuracy: 0.7847 - val_loss: 0.5490 - val_accuracy: 0.7370
# Epoch 12/30
# 5/5 [==============================] - 0s 88ms/step - loss: 0.4372 - accuracy: 0.8172 - val_loss: 0.6501 - val_accuracy: 0.7045
# Epoch 13/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4094 - accuracy: 0.8383 - val_loss: 0.5385 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.3784 - accuracy: 0.8457 - val_loss: 0.6095 - val_accuracy: 0.7045
# Epoch 15/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4073 - accuracy: 0.8213 - val_loss: 0.5472 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6289 - accuracy: 0.7135
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 64, 100)           806300
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 210ms/step - loss: 0.7631 - accuracy: 0.5150 - val_loss: 0.6819 - val_accuracy: 0.5325
# Epoch 2/30
# 5/5 [==============================] - 1s 111ms/step - loss: 0.7460 - accuracy: 0.5272 - val_loss: 0.6711 - val_accuracy: 0.5455
# Epoch 3/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.7008 - accuracy: 0.5589 - val_loss: 0.6479 - val_accuracy: 0.6006
# Epoch 4/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.6462 - accuracy: 0.6279 - val_loss: 0.5996 - val_accuracy: 0.7305
# Epoch 5/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.6058 - accuracy: 0.6799 - val_loss: 0.5857 - val_accuracy: 0.6916
# Epoch 6/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.5836 - accuracy: 0.7149 - val_loss: 0.5692 - val_accuracy: 0.6981
# Epoch 7/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5539 - accuracy: 0.7222 - val_loss: 0.5881 - val_accuracy: 0.6981
# Epoch 8/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.5123 - accuracy: 0.7620 - val_loss: 0.5780 - val_accuracy: 0.6851
# Epoch 9/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.5125 - accuracy: 0.7652 - val_loss: 0.5209 - val_accuracy: 0.7630
# Epoch 10/30
# 5/5 [==============================] - 0s 89ms/step - loss: 0.5335 - accuracy: 0.7595 - val_loss: 0.5268 - val_accuracy: 0.7500
# Epoch 11/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4259 - accuracy: 0.8270 - val_loss: 0.5443 - val_accuracy: 0.7630
# Epoch 12/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.3698 - accuracy: 0.8505 - val_loss: 0.6646 - val_accuracy: 0.6623
# Epoch 13/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4291 - accuracy: 0.8205 - val_loss: 0.5235 - val_accuracy: 0.7792
# Epoch 14/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.3139 - accuracy: 0.8814 - val_loss: 0.5335 - val_accuracy: 0.7597
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6619 - accuracy: 0.6725
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 64, 100)           806300
#
#  lstm_3 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 192ms/step - loss: 0.8472 - accuracy: 0.4760 - val_loss: 0.6901 - val_accuracy: 0.5097
# Epoch 2/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7385 - accuracy: 0.5142 - val_loss: 0.6762 - val_accuracy: 0.5422
# Epoch 3/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7035 - accuracy: 0.5621 - val_loss: 0.6605 - val_accuracy: 0.5942
# Epoch 4/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6779 - accuracy: 0.5938 - val_loss: 0.5889 - val_accuracy: 0.7143
# Epoch 5/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6574 - accuracy: 0.6320 - val_loss: 0.5762 - val_accuracy: 0.7305
# Epoch 6/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6122 - accuracy: 0.6694 - val_loss: 0.5681 - val_accuracy: 0.7175
# Epoch 7/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5865 - accuracy: 0.6929 - val_loss: 0.6381 - val_accuracy: 0.6169
# Epoch 8/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5250 - accuracy: 0.7604 - val_loss: 0.6493 - val_accuracy: 0.6169
# Epoch 9/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5116 - accuracy: 0.7612 - val_loss: 0.5688 - val_accuracy: 0.7110
# Epoch 10/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.5233 - accuracy: 0.7522 - val_loss: 0.5387 - val_accuracy: 0.7435
# Epoch 11/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4386 - accuracy: 0.8172 - val_loss: 0.5511 - val_accuracy: 0.7468
# Epoch 12/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4132 - accuracy: 0.8327 - val_loss: 0.6080 - val_accuracy: 0.7013
# Epoch 13/30
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3905 - accuracy: 0.8383 - val_loss: 0.6707 - val_accuracy: 0.6721
# Epoch 14/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4206 - accuracy: 0.8099 - val_loss: 0.5535 - val_accuracy: 0.7565
# Epoch 15/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3406 - accuracy: 0.8668 - val_loss: 0.6423 - val_accuracy: 0.7338
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8207 - accuracy: 0.6784
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 64, 100)           806300
#
#  lstm_4 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 300ms/step - loss: 0.7678 - accuracy: 0.5215 - val_loss: 0.6741 - val_accuracy: 0.6591
# Epoch 2/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.7220 - accuracy: 0.5410 - val_loss: 0.6437 - val_accuracy: 0.6753
# Epoch 3/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6794 - accuracy: 0.6011 - val_loss: 0.5889 - val_accuracy: 0.6948
# Epoch 4/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6740 - accuracy: 0.6401 - val_loss: 0.5554 - val_accuracy: 0.7565
# Epoch 5/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5605 - accuracy: 0.7344 - val_loss: 0.5332 - val_accuracy: 0.7468
# Epoch 6/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.5966 - accuracy: 0.7067 - val_loss: 0.5947 - val_accuracy: 0.6948
# Epoch 7/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5044 - accuracy: 0.7677 - val_loss: 0.5213 - val_accuracy: 0.7662
# Epoch 8/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.5417 - accuracy: 0.7474 - val_loss: 0.5241 - val_accuracy: 0.7565
# Epoch 9/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4212 - accuracy: 0.8091 - val_loss: 0.5671 - val_accuracy: 0.7435
# Epoch 10/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.4841 - accuracy: 0.7937 - val_loss: 0.5096 - val_accuracy: 0.7597
# Epoch 11/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.3553 - accuracy: 0.8562 - val_loss: 0.5258 - val_accuracy: 0.7727
# Epoch 12/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4583 - accuracy: 0.8156 - val_loss: 0.5151 - val_accuracy: 0.7727
# Epoch 13/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.3330 - accuracy: 0.8725 - val_loss: 0.6100 - val_accuracy: 0.7370
# Epoch 14/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3562 - accuracy: 0.8595 - val_loss: 0.5793 - val_accuracy: 0.7597
# Epoch 15/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3107 - accuracy: 0.8765 - val_loss: 0.5356 - val_accuracy: 0.7857
# 6/6 [==============================] - 0s 9ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6522 - accuracy: 0.7193
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 64, 100)           806300
#
#  lstm_5 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 191ms/step - loss: 0.7677 - accuracy: 0.5085 - val_loss: 0.6842 - val_accuracy: 0.5909
# Epoch 2/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7651 - accuracy: 0.5004 - val_loss: 0.6660 - val_accuracy: 0.5714
# Epoch 3/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.7134 - accuracy: 0.5524 - val_loss: 0.6263 - val_accuracy: 0.6818
# Epoch 4/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.6742 - accuracy: 0.6182 - val_loss: 0.5816 - val_accuracy: 0.7208
# Epoch 5/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6357 - accuracy: 0.6637 - val_loss: 0.6376 - val_accuracy: 0.6169
# Epoch 6/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6062 - accuracy: 0.6897 - val_loss: 0.5572 - val_accuracy: 0.7305
# Epoch 7/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5704 - accuracy: 0.7279 - val_loss: 0.5310 - val_accuracy: 0.7630
# Epoch 8/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5201 - accuracy: 0.7660 - val_loss: 0.6876 - val_accuracy: 0.6558
# Epoch 9/30
# 5/5 [==============================] - 1s 106ms/step - loss: 0.5021 - accuracy: 0.7701 - val_loss: 0.5210 - val_accuracy: 0.7565
# Epoch 10/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4987 - accuracy: 0.7855 - val_loss: 0.5335 - val_accuracy: 0.7403
# Epoch 11/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4433 - accuracy: 0.8156 - val_loss: 0.5286 - val_accuracy: 0.7500
# Epoch 12/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4493 - accuracy: 0.8140 - val_loss: 0.5230 - val_accuracy: 0.7630
# Epoch 13/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3835 - accuracy: 0.8530 - val_loss: 0.5935 - val_accuracy: 0.7403
# Epoch 14/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3446 - accuracy: 0.8668 - val_loss: 0.5615 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7147 - accuracy: 0.6901
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 64, 100)           806300
#
#  lstm_6 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 188ms/step - loss: 0.7412 - accuracy: 0.5272 - val_loss: 0.6832 - val_accuracy: 0.6526
# Epoch 2/30
# 5/5 [==============================] - 0s 91ms/step - loss: 0.7291 - accuracy: 0.5102 - val_loss: 0.6501 - val_accuracy: 0.6299
# Epoch 3/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7080 - accuracy: 0.5556 - val_loss: 0.6158 - val_accuracy: 0.7273
# Epoch 4/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6671 - accuracy: 0.6190 - val_loss: 0.5896 - val_accuracy: 0.7435
# Epoch 5/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.5909 - accuracy: 0.6864 - val_loss: 0.7130 - val_accuracy: 0.5519
# Epoch 6/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.6346 - accuracy: 0.6548 - val_loss: 0.5453 - val_accuracy: 0.7370
# Epoch 7/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.5781 - accuracy: 0.7076 - val_loss: 0.5365 - val_accuracy: 0.7468
# Epoch 8/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5234 - accuracy: 0.7620 - val_loss: 0.5403 - val_accuracy: 0.7370
# Epoch 9/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4812 - accuracy: 0.7896 - val_loss: 0.5386 - val_accuracy: 0.7532
# Epoch 10/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.4669 - accuracy: 0.8067 - val_loss: 0.6357 - val_accuracy: 0.6786
# Epoch 11/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4317 - accuracy: 0.8253 - val_loss: 0.5223 - val_accuracy: 0.7792
# Epoch 12/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4542 - accuracy: 0.7929 - val_loss: 0.5249 - val_accuracy: 0.7468
# Epoch 13/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3975 - accuracy: 0.8448 - val_loss: 0.5863 - val_accuracy: 0.7565
# Epoch 14/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3458 - accuracy: 0.8643 - val_loss: 0.5325 - val_accuracy: 0.7727
# Epoch 15/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3225 - accuracy: 0.8798 - val_loss: 0.7265 - val_accuracy: 0.7078
# Epoch 16/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3840 - accuracy: 0.8497 - val_loss: 0.5433 - val_accuracy: 0.7630
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6374 - accuracy: 0.7076
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 64, 100)           806300
#
#  lstm_7 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 186ms/step - loss: 0.7396 - accuracy: 0.5321 - val_loss: 0.6845 - val_accuracy: 0.5260
# Epoch 2/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7308 - accuracy: 0.5223 - val_loss: 0.7155 - val_accuracy: 0.5260
# Epoch 3/30
# 5/5 [==============================] - 0s 95ms/step - loss: 0.7219 - accuracy: 0.5532 - val_loss: 0.6183 - val_accuracy: 0.7338
# Epoch 4/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6564 - accuracy: 0.6336 - val_loss: 0.5911 - val_accuracy: 0.7208
# Epoch 5/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.6084 - accuracy: 0.6783 - val_loss: 0.5949 - val_accuracy: 0.7013
# Epoch 6/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.5759 - accuracy: 0.7132 - val_loss: 0.5310 - val_accuracy: 0.7727
# Epoch 7/30
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5677 - accuracy: 0.7335 - val_loss: 0.5310 - val_accuracy: 0.7565
# Epoch 8/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5378 - accuracy: 0.7327 - val_loss: 0.5426 - val_accuracy: 0.7338
# Epoch 9/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4457 - accuracy: 0.8123 - val_loss: 0.5913 - val_accuracy: 0.7240
# Epoch 10/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.4999 - accuracy: 0.7725 - val_loss: 0.5264 - val_accuracy: 0.7565
# Epoch 11/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4190 - accuracy: 0.8286 - val_loss: 0.6887 - val_accuracy: 0.6558
# Epoch 12/30
# 5/5 [==============================] - 0s 100ms/step - loss: 0.4295 - accuracy: 0.8115 - val_loss: 0.5652 - val_accuracy: 0.7435
# Epoch 13/30
# 5/5 [==============================] - 0s 102ms/step - loss: 0.3316 - accuracy: 0.8781 - val_loss: 0.5532 - val_accuracy: 0.7662
# Epoch 14/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.3752 - accuracy: 0.8416 - val_loss: 0.5934 - val_accuracy: 0.6786
# Epoch 15/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.3770 - accuracy: 0.8400 - val_loss: 0.5529 - val_accuracy: 0.7403
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6710 - accuracy: 0.6784
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 100)           806300
#
#  lstm_8 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 2s 197ms/step - loss: 0.8228 - accuracy: 0.4801 - val_loss: 0.6903 - val_accuracy: 0.5227
# Epoch 2/30
# 5/5 [==============================] - 0s 93ms/step - loss: 0.7454 - accuracy: 0.5158 - val_loss: 0.6713 - val_accuracy: 0.5584
# Epoch 3/30
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7085 - accuracy: 0.5703 - val_loss: 0.6406 - val_accuracy: 0.7110
# Epoch 4/30
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6901 - accuracy: 0.5686 - val_loss: 0.6295 - val_accuracy: 0.6299
# Epoch 5/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.6443 - accuracy: 0.6296 - val_loss: 0.7947 - val_accuracy: 0.5649
# Epoch 6/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.6359 - accuracy: 0.6637 - val_loss: 0.5591 - val_accuracy: 0.7500
# Epoch 7/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.5653 - accuracy: 0.7124 - val_loss: 0.5480 - val_accuracy: 0.7500
# Epoch 8/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5688 - accuracy: 0.7206 - val_loss: 0.5836 - val_accuracy: 0.6818
# Epoch 9/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.5254 - accuracy: 0.7360 - val_loss: 0.5481 - val_accuracy: 0.7273
# Epoch 10/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.5042 - accuracy: 0.7725 - val_loss: 0.5347 - val_accuracy: 0.7532
# Epoch 11/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4656 - accuracy: 0.7945 - val_loss: 0.5343 - val_accuracy: 0.7630
# Epoch 12/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4509 - accuracy: 0.8002 - val_loss: 0.5330 - val_accuracy: 0.7565
# Epoch 13/30
# 5/5 [==============================] - 0s 103ms/step - loss: 0.4130 - accuracy: 0.8327 - val_loss: 0.5640 - val_accuracy: 0.7240
# Epoch 14/30
# 5/5 [==============================] - 0s 101ms/step - loss: 0.4025 - accuracy: 0.8359 - val_loss: 0.5556 - val_accuracy: 0.7338
# Epoch 15/30
# 5/5 [==============================] - 1s 118ms/step - loss: 0.3436 - accuracy: 0.8741 - val_loss: 0.6955 - val_accuracy: 0.7110
# Epoch 16/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.3775 - accuracy: 0.8505 - val_loss: 0.5613 - val_accuracy: 0.7662
# Epoch 17/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.3337 - accuracy: 0.8708 - val_loss: 0.6062 - val_accuracy: 0.7240
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6394 - accuracy: 0.6901
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 64, 100)           806300
#
#  lstm_9 (LSTM)               (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 198ms/step - loss: 0.7351 - accuracy: 0.5158 - val_loss: 0.7034 - val_accuracy: 0.4708
# Epoch 2/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7254 - accuracy: 0.5305 - val_loss: 0.6766 - val_accuracy: 0.5227
# Epoch 3/30
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6857 - accuracy: 0.5995 - val_loss: 0.6667 - val_accuracy: 0.5844
# Epoch 4/30
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6624 - accuracy: 0.6377 - val_loss: 0.5724 - val_accuracy: 0.7370
# Epoch 5/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5842 - accuracy: 0.7043 - val_loss: 0.5390 - val_accuracy: 0.7597
# Epoch 6/30
# 5/5 [==============================] - 1s 120ms/step - loss: 0.5935 - accuracy: 0.7132 - val_loss: 0.5475 - val_accuracy: 0.7435
# Epoch 7/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.5593 - accuracy: 0.7311 - val_loss: 0.5234 - val_accuracy: 0.7565
# Epoch 8/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5301 - accuracy: 0.7539 - val_loss: 0.5367 - val_accuracy: 0.7500
# Epoch 9/30
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4750 - accuracy: 0.7953 - val_loss: 0.5554 - val_accuracy: 0.7273
# Epoch 10/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4494 - accuracy: 0.8197 - val_loss: 0.5829 - val_accuracy: 0.7468
# Epoch 11/30
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4695 - accuracy: 0.7839 - val_loss: 0.5805 - val_accuracy: 0.7110
# Epoch 12/30
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4141 - accuracy: 0.8335 - val_loss: 0.6836 - val_accuracy: 0.6201
# 6/6 [==============================] - 0s 11ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6849 - accuracy: 0.6550
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 64, 100)           806300
#
#  lstm_10 (LSTM)              (None, 64)                42240
#
#  FC1 (Dense)                 (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  FC2 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 852,830
# Trainable params: 852,830
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s 198ms/step - loss: 1.0601 - accuracy: 0.4736 - val_loss: 0.7178 - val_accuracy: 0.4740
# Epoch 2/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.7654 - accuracy: 0.5110 - val_loss: 0.6948 - val_accuracy: 0.5162
# Epoch 3/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.7334 - accuracy: 0.5118 - val_loss: 0.6866 - val_accuracy: 0.5552
# Epoch 4/30
# 5/5 [==============================] - 1s 119ms/step - loss: 0.7235 - accuracy: 0.5207 - val_loss: 0.6814 - val_accuracy: 0.6071
# Epoch 5/30
# 5/5 [==============================] - 1s 110ms/step - loss: 0.7367 - accuracy: 0.5191 - val_loss: 0.6725 - val_accuracy: 0.6104
# Epoch 6/30
# 5/5 [==============================] - 1s 109ms/step - loss: 0.6971 - accuracy: 0.5565 - val_loss: 0.6810 - val_accuracy: 0.5065
# Epoch 7/30
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6634 - accuracy: 0.5906 - val_loss: 0.7181 - val_accuracy: 0.4805
# Epoch 8/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6389 - accuracy: 0.6377 - val_loss: 0.6942 - val_accuracy: 0.5227
# Epoch 9/30
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6150 - accuracy: 0.6686 - val_loss: 0.6061 - val_accuracy: 0.6656
# Epoch 10/30
# 5/5 [==============================] - 1s 154ms/step - loss: 0.6070 - accuracy: 0.6751 - val_loss: 0.5630 - val_accuracy: 0.7273
# Epoch 11/30
# 5/5 [==============================] - 1s 172ms/step - loss: 0.5462 - accuracy: 0.7441 - val_loss: 0.6659 - val_accuracy: 0.5844
# Epoch 12/30
# 5/5 [==============================] - 1s 113ms/step - loss: 0.5102 - accuracy: 0.7628 - val_loss: 0.6900 - val_accuracy: 0.5844
# Epoch 13/30
# 5/5 [==============================] - 1s 116ms/step - loss: 0.5665 - accuracy: 0.7189 - val_loss: 0.5612 - val_accuracy: 0.7078
# Epoch 14/30
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5027 - accuracy: 0.7693 - val_loss: 0.5835 - val_accuracy: 0.7078
# Epoch 15/30
# 5/5 [==============================] - 1s 108ms/step - loss: 0.4403 - accuracy: 0.8075 - val_loss: 0.6843 - val_accuracy: 0.6591
# Epoch 16/30
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4660 - accuracy: 0.7880 - val_loss: 0.5443 - val_accuracy: 0.7500
# Epoch 17/30
# 5/5 [==============================] - 1s 155ms/step - loss: 0.3972 - accuracy: 0.8440 - val_loss: 0.5708 - val_accuracy: 0.7305
# Epoch 18/30
# 5/5 [==============================] - 1s 143ms/step - loss: 0.4015 - accuracy: 0.8392 - val_loss: 0.5473 - val_accuracy: 0.7532
# Epoch 19/30
# 5/5 [==============================] - 1s 159ms/step - loss: 0.3500 - accuracy: 0.8643 - val_loss: 0.6677 - val_accuracy: 0.6786
# Epoch 20/30
# 5/5 [==============================] - 1s 115ms/step - loss: 0.3620 - accuracy: 0.8538 - val_loss: 0.5796 - val_accuracy: 0.7435
# Epoch 21/30
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3284 - accuracy: 0.8733 - val_loss: 0.5596 - val_accuracy: 0.7565
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6656 - accuracy: 0.7076

# %%
print('accuracy:'+str(sum(score_list)/len(score_list)))
# Out:
# accuracy:0.691228061914444

# %%
score_list.sort()

# %%
score_list
# Out:
# [0.6549707651138306,
#  0.6725146174430847,
#  0.6783625483512878,
#  0.6783625483512878,
#  0.6900584697723389,
#  0.6900584697723389,
#  0.707602322101593,
#  0.707602322101593,
#  0.7134503126144409,
#  0.719298243522644]
